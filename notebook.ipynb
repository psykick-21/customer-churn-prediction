# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

import optuna
from sklearn.model_selection import cross_validate

import sklearn
import category_encoders
from sklearn import set_config
from sklearn.model_selection import KFold, RandomizedSearchCV, GridSearchCV, train_test_split
import pickle
set_config(transform_output = "pandas")

import optuna.logging
optuna.logging.set_verbosity(optuna.logging.WARNING)
import os

# %%
# reading datasets
with open('data/cleaned/xtrain.pkl', 'rb') as f:
    xtrain = pickle.load(f)
with open('data/cleaned/xtest.pkl', 'rb') as f:
    xtest = pickle.load(f)
with open('data/cleaned/xval.pkl', 'rb') as f:
    xval = pickle.load(f)
with open('data/cleaned/ytrain.pkl', 'rb') as f:
    ytrain = pickle.load(f)
with open('data/cleaned/ytest.pkl', 'rb') as f:
    ytest = pickle.load(f)
with open('data/cleaned/yval.pkl', 'rb') as f:
    yval = pickle.load(f)

# %% [markdown]
# ## Modeling

# %%
# defining some utility functions
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, log_loss

# dataframe to store model performance metrics
model_performance = pd.DataFrame(columns=['model_name', 'train_accuracy', 'test_accuracy', 'train_precision', 'test_precision',
                                          'train_recall', 'test_recall', 'train_f1', 'test_f1', 'train_roc_auc', 'test_roc_auc', 
                                          'train_log_loss', 'test_log_loss'])
# dictionary to store the models
estimators = {}

# function to calculate model performance metrics
def model_scorer(clf, x, y, prefix=''):
    ypred = clf.predict(x)
    yprob = clf.predict_proba(x)[:, 1]
    score_dict = {
        prefix+'accuracy': np.round(accuracy_score(y, ypred),3),
        prefix+'precision': np.round(precision_score(y, ypred),3),
        prefix+'recall': np.round(recall_score(y, ypred),3),
        prefix+'f1': np.round(f1_score(y, ypred),3),
        prefix+'roc_auc': np.round(roc_auc_score(y, yprob),3),
        prefix+'log_loss': np.round(log_loss(y, yprob),3)
    }
    return score_dict

# function to add model performance to the dataframe and model to the dictionary
def add_model_performance(model_name, clf, xtrain=xtrain, ytrain=ytrain, xtest=xtest, ytest=ytest, df=model_performance, model_dict=estimators):
    train_scores = model_scorer(clf, xtrain, ytrain, prefix='train_')
    test_scores = model_scorer(clf, xtest, ytest, prefix='test_')
    train_scores.update(test_scores)
    train_scores['model_name'] = model_name
    df.loc[df.shape[0]] = train_scores
    model_dict[model_name] = clf
    return df,model_dict

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# defining the objective function for the optimization
def objective(trial, xtrain, ytrain, kf):
    params = {
        'C': trial.suggest_loguniform('C', 1e-3, 1e3),
        'penalty': trial.suggest_categorical('penalty', ['l1', 'l2']),
        'solver': trial.suggest_categorical('solver', ['liblinear'])
    }
    model = LogisticRegression(**params)
    scores = cross_validate(model, xtrain, ytrain, cv=kf, scoring='neg_log_loss', n_jobs=-1)
    loss = -scores['test_score'].mean()
    return loss

# optimization using kfold cross validation
kf = KFold(n_splits=3, shuffle=True, random_state=42)
obj_func = lambda trial: objective(trial, xtrain.values, ytrain.values.ravel(), kf)
study = optuna.create_study(direction='minimize')
study.optimize(obj_func, n_trials=30)

# printing the best score and best parameters
print(f"Best score: {study.best_value:5f}")
print(f"Best params: {study.best_params}")

# training the model with the best parameters
best_model = LogisticRegression(**study.best_params).fit(xtrain.values, ytrain.values.ravel())

# adding the model performance to the dataframe and model to the dictionary
model_performance, estimators = add_model_performance(model_name='LogisticRegression', clf=best_model)

# displaying the model performance
display(model_performance)
# Out:
# Best score: 0.390138
# Best params: {'C': 0.6472139377148375, 'penalty': 'l2', 'solver': 'liblinear'}
#            model_name  train_accuracy  test_accuracy  train_precision  \
# 0  LogisticRegression           0.848          0.849            0.874
#
#    test_precision  train_recall  test_recall  train_f1  test_f1  \
# 0           0.873         0.849        0.852     0.861    0.863
#
#    train_roc_auc  test_roc_auc  train_log_loss  test_log_loss
# 0          0.908          0.91            0.39          0.388

# %% [markdown]
# #### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

def objective(trial, xtrain, ytrain, kf):
    params = {
        'max_depth': trial.suggest_int('max_depth', 1, 300, 7),
        'min_samples_split': trial.suggest_int('min_samples_split', 50, 1000, 50),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 50, 1000, 50),
    }
    model = DecisionTreeClassifier(**params)
    scores = cross_validate(model, xtrain, ytrain, cv=kf, scoring='neg_log_loss', n_jobs=-1)
    loss = -scores['test_score'].mean()
    return loss

kf = KFold(n_splits=3, shuffle=True, random_state=42)
obj_func = lambda trial: objective(trial, xtrain.values, ytrain.values.ravel(), kf)
study = optuna.create_study(direction='minimize',)
study.optimize(obj_func, n_trials=50)

print(f"Best score: {study.best_value:5f}")
print(f"Best params: {study.best_params}")

best_model = DecisionTreeClassifier(**study.best_params).fit(xtrain.values, ytrain.values.ravel())
model_performance, estimators = add_model_performance(model_name='DecisionTreeClassifier', clf=best_model)

display(model_performance)
# Out:
# Best score: 0.193432
# Best params: {'max_depth': 113, 'min_samples_split': 600, 'min_samples_leaf': 100}
#                model_name  train_accuracy  test_accuracy  train_precision  \
# 0      LogisticRegression           0.848          0.849            0.874
# 1  DecisionTreeClassifier           0.935          0.935            0.897
#
#    test_precision  train_recall  test_recall  train_f1  test_f1  \
# 0           0.873         0.849        0.852     0.861    0.863
# 1           0.898         0.997        0.997     0.944    0.945
#
#    train_roc_auc  test_roc_auc  train_log_loss  test_log_loss
# 0          0.908         0.910           0.390          0.388
# 1          0.962         0.953           0.182          0.191

# %% [markdown]
# #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

def objective(trial, xtrain, ytrain, kf):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1001, 50),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 100, 10),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 100, 10),
    }
    model = RandomForestClassifier(**params)
    scores = cross_validate(model, xtrain, ytrain, cv=kf, scoring='neg_log_loss', n_jobs=-1)
    loss = -scores['test_score'].mean()
    return loss

kf = KFold(n_splits=3, shuffle=True, random_state=42)
obj_func = lambda trial: objective(trial, xtrain.values, ytrain.values.ravel(), kf)
study = optuna.create_study(direction='minimize',)
study.optimize(obj_func, n_trials=5)

print(f"Best score: {study.best_value:5f}")
print(f"Best params: {study.best_params}")

best_model = RandomForestClassifier(**study.best_params).fit(xtrain.values, ytrain.values.ravel())
model_performance, estimators = add_model_performance(model_name='RandomForestClassifier', clf=best_model)

display(model_performance)
# Out:
# Best score: 0.189381
# Best params: {'n_estimators': 800, 'min_samples_split': 62, 'min_samples_leaf': 11}
#                model_name  train_accuracy  test_accuracy  train_precision  \
# 0      LogisticRegression           0.848          0.849            0.874
# 1  DecisionTreeClassifier           0.935          0.935            0.897
# 2  RandomForestClassifier           0.936          0.936            0.898
#
#    test_precision  train_recall  test_recall  train_f1  test_f1  \
# 0           0.873         0.849        0.852     0.861    0.863
# 1           0.898         0.997        0.997     0.944    0.945
# 2           0.898         0.998        0.998     0.945    0.946
#
#    train_roc_auc  test_roc_auc  train_log_loss  test_log_loss
# 0          0.908         0.910           0.390          0.388
# 1          0.962         0.953           0.182          0.191
# 2          0.996         0.954           0.162          0.186

# %% [markdown]
# #### XGBoost Classifier

# %%
from xgboost import XGBClassifier

def objective(trial, xtrain, ytrain, kf):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 10, 501, 50),
        'max_depth': trial.suggest_categorical('max_depth', [1,2]),
    }
    model = XGBClassifier(**params)
    scores = cross_validate(model, xtrain, ytrain, cv=kf, scoring='neg_log_loss', n_jobs=-1)
    loss = -scores['test_score'].mean()
    return loss

kf = KFold(n_splits=3, shuffle=True, random_state=42)
obj_func = lambda trial: objective(trial, xtrain.values, ytrain.values.ravel(), kf)
study = optuna.create_study(direction='minimize',)
study.optimize(obj_func, n_trials=50)

print(f"Best score: {study.best_value:5f}")
print(f"Best params: {study.best_params}")

best_model = XGBClassifier(**study.best_params).fit(xtrain.values, ytrain.values.ravel())
model_performance, estimators = add_model_performance(model_name='XGBClassifier', clf=best_model)

display(model_performance)
# Out:
# Best score: 0.254015
# Best params: {'n_estimators': 460, 'max_depth': 2}
#                model_name  train_accuracy  test_accuracy  train_precision  \
# 0      LogisticRegression           0.848          0.849            0.874
# 1  DecisionTreeClassifier           0.935          0.935            0.897
# 2  RandomForestClassifier           0.936          0.936            0.898
# 3           XGBClassifier           0.914          0.914            0.900
#
#    test_precision  train_recall  test_recall  train_f1  test_f1  \
# 0           0.873         0.849        0.852     0.861    0.863
# 1           0.898         0.997        0.997     0.944    0.945
# 2           0.898         0.998        0.998     0.945    0.946
# 3           0.900         0.952        0.951     0.925    0.925
#
#    train_roc_auc  test_roc_auc  train_log_loss  test_log_loss
# 0          0.908         0.910           0.390          0.388
# 1          0.962         0.953           0.182          0.191
# 2          0.996         0.954           0.162          0.186
# 3          0.950         0.949           0.251          0.252

# %% [markdown]
# #### KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

def objective(trial, xtrain, ytrain, kf):
    params = {
        'n_neighbors': trial.suggest_int('n_neighbors', 1, 20, 4),
        'weights': trial.suggest_categorical('weights', ['uniform', 'distance']),
    }
    model = KNeighborsClassifier(**params)
    scores = cross_validate(model, xtrain, ytrain, cv=kf, scoring='accuracy', n_jobs=-1)
    loss = scores['test_score'].mean()
    return loss

xtrain_sample = xtrain.sample(frac=0.5, random_state=42)
ytrain_sample = ytrain.loc[xtrain_sample.index]
kf = KFold(n_splits=3, shuffle=True, random_state=42)
obj_func = lambda trial: objective(trial, xtrain_sample.values, ytrain_sample.values.ravel(), kf)
study = optuna.create_study(direction='maximize',)
study.optimize(obj_func, n_trials=10)

print(f"Best score: {study.best_value:5f}")
print(f"Best params: {study.best_params}")

best_model = KNeighborsClassifier(**study.best_params).fit(xtrain.values, ytrain.values.ravel())
model_performance, estimators = add_model_performance(model_name='KNeighborsClassifier', clf=best_model)

display(model_performance)
# Out:
# Best score: 0.898761
# Best params: {'n_neighbors': 9, 'weights': 'distance'}
#                model_name  train_accuracy  test_accuracy  train_precision  \
# 0      LogisticRegression           0.848          0.849            0.874
# 1  DecisionTreeClassifier           0.935          0.935            0.897
# 2  RandomForestClassifier           0.936          0.936            0.898
# 3           XGBClassifier           0.914          0.914            0.900
# 4    KNeighborsClassifier           1.000          0.907            1.000
#
#    test_precision  train_recall  test_recall  train_f1  test_f1  \
# 0           0.873         0.849        0.852     0.861    0.863
# 1           0.898         0.997        0.997     0.944    0.945
# 2           0.898         0.998        0.998     0.945    0.946
# 3           0.900         0.952        0.951     0.925    0.925
# 4           0.901         1.000        0.935     1.000    0.918
#
#    train_roc_auc  test_roc_auc  train_log_loss  test_log_loss
# 0          0.908         0.910           0.390          0.388
# 1          0.962         0.953           0.182          0.191
# 2          0.996         0.954           0.162          0.186
# 3          0.950         0.949           0.251          0.252
# 4          1.000         0.938           0.000          0.896

# %% [markdown]
# #### Stacking Classifier with Logistic Regression as Meta Classifier

# %%
from sklearn.ensemble import StackingClassifier

def objective(trial, xtrain, ytrain, kf, estimators_list):
    params = {
        'C': trial.suggest_loguniform('C', 1e-3, 1e3),
        'penalty': trial.suggest_categorical('penalty', ['l1', 'l2']),
        'solver': trial.suggest_categorical('solver', ['liblinear'])
    }
    model = LogisticRegression(**params)
    stacker = StackingClassifier(estimators=estimators_list, final_estimator=model, cv=None, n_jobs=-1)
    scores = cross_validate(stacker, xtrain.values, ytrain.values.ravel(), cv=kf, scoring='neg_log_loss', n_jobs=-1)
    loss = -scores['test_score'].mean()
    return loss

estimators_list = [(k, v) for k, v in estimators.items()]
kf = KFold(n_splits=3, shuffle=True, random_state=42)
obj_func = lambda trial: objective(trial, xval, yval, kf, estimators_list)
study = optuna.create_study(direction='minimize',)
study.optimize(obj_func, n_trials=5)

print(f"Best score: {study.best_value:5f}")
print(f"Best params: {study.best_params}")

best_model = StackingClassifier(estimators=estimators_list, final_estimator=LogisticRegression(**study.best_params), cv=None, n_jobs=-1)
best_model.fit(xval.values, yval.values.ravel())
model_performance, estimators = add_model_performance(model_name='StackingLR', clf=best_model)

display(model_performance)
# Out:
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# Best score: 0.201541
# Best params: {'C': 773.9379121439813, 'penalty': 'l1', 'solver': 'liblinear'}
#                model_name  train_accuracy  test_accuracy  train_precision  \
# 0      LogisticRegression           0.848          0.849            0.874
# 1  DecisionTreeClassifier           0.935          0.935            0.897
# 2  RandomForestClassifier           0.936          0.936            0.898
# 3           XGBClassifier           0.914          0.914            0.900
# 4    KNeighborsClassifier           1.000          0.907            1.000
# 5              StackingLR           0.934          0.934            0.898
#
#    test_precision  train_recall  test_recall  train_f1  test_f1  \
# 0           0.873         0.849        0.852     0.861    0.863
# 1           0.898         0.997        0.997     0.944    0.945
# 2           0.898         0.998        0.998     0.945    0.946
# 3           0.900         0.952        0.951     0.925    0.925
# 4           0.901         1.000        0.935     1.000    0.918
# 5           0.898         0.994        0.994     0.943    0.944
#
#    train_roc_auc  test_roc_auc  train_log_loss  test_log_loss
# 0          0.908         0.910           0.390          0.388
# 1          0.962         0.953           0.182          0.191
# 2          0.996         0.954           0.162          0.186
# 3          0.950         0.949           0.251          0.252
# 4          1.000         0.938           0.000          0.896
# 5          0.953         0.953           0.198          0.197

# %% [markdown]
# #### Stacking Classifier with XGBoost as final estimator

# %%
## optuna tuning
def objective(trial, xtrain, ytrain, kf, estimators_list):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 10, 501, 50),
        'max_depth': trial.suggest_categorical('max_depth', [1,2]),
    }
    model = XGBClassifier(**params)
    stacker = StackingClassifier(estimators=estimators_list, final_estimator=model, cv=None, n_jobs=-1)
    scores = cross_validate(stacker, xtrain, ytrain, cv=kf, scoring='neg_log_loss', n_jobs=-1)
    loss = -scores['test_score'].mean()
    return loss

estimators_list = [(k, v) for k, v in estimators.items()]
kf = KFold(n_splits=3, shuffle=True, random_state=42)
obj_func = lambda trial: objective(trial, xval.values, yval.values.ravel(), kf, estimators_list)
study = optuna.create_study(direction='minimize',)
study.optimize(obj_func, n_trials=1)

print(f"Best score: {study.best_value:5f}")
print(f"Best params: {study.best_params}")

best_model = StackingClassifier(estimators=estimators_list, final_estimator=XGBClassifier(**study.best_params), cv=None, n_jobs=-1)
best_model.fit(xval.values, yval.values.ravel())
model_performance, estimators = add_model_performance(model_name='StackingXGB', clf=best_model)

display(model_performance)
# Out:
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# Best score: 0.183139
# Best params: {'n_estimators': 110, 'max_depth': 2}
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
#                model_name  train_accuracy  test_accuracy  train_precision  \
# 0      LogisticRegression           0.848          0.849            0.874
# 1  DecisionTreeClassifier           0.935          0.935            0.897
# 2  RandomForestClassifier           0.936          0.936            0.898
# 3           XGBClassifier           0.914          0.914            0.900
# 4    KNeighborsClassifier           1.000          0.907            1.000
# 5              StackingLR           0.934          0.934            0.898
# 6             StackingXGB           0.936          0.937            0.897
#
#    test_precision  train_recall  test_recall  train_f1  test_f1  \
# 0           0.873         0.849        0.852     0.861    0.863
# 1           0.898         0.997        0.997     0.944    0.945
# 2           0.898         0.998        0.998     0.945    0.946
# 3           0.900         0.952        0.951     0.925    0.925
# 4           0.901         1.000        0.935     1.000    0.918
# 5           0.898         0.994        0.994     0.943    0.944
# 6           0.898         0.999        0.999     0.946    0.946
#
#    train_roc_auc  test_roc_auc  train_log_loss  test_log_loss
# 0          0.908         0.910           0.390          0.388
# 1          0.962         0.953           0.182          0.191
# 2          0.996         0.954           0.162          0.186
# 3          0.950         0.949           0.251          0.252
# 4          1.000         0.938           0.000          0.896
# 5          0.953         0.953           0.198          0.197
# 6          0.953         0.953           0.182          0.181

# %% [markdown]
# #### Support Vector Classifier

# %%
from sklearn.svm import SVC

def objective(trial, xtrain, ytrain, kf):
    params = {
        'C': trial.suggest_loguniform('C', 1e-3, 1e3),
        'kernel': trial.suggest_categorical('kernel', ['poly', 'rbf', 'sigmoid']),
        'degree': trial.suggest_int('degree', 2, 4),
        'probability': True,
    }
    model = SVC(**params)
    scores = cross_validate(model, xtrain, ytrain, cv=kf, scoring='neg_log_loss', n_jobs=-1)
    loss = -scores['test_score'].mean()
    return loss

xtrain_sample = xtrain.sample(frac=0.1, random_state=42)
ytrain_sample = ytrain.loc[xtrain_sample.index]
kf = KFold(n_splits=3, shuffle=True, random_state=42)
obj_func = lambda trial: objective(trial, xtrain_sample.values, ytrain_sample.values.ravel(), kf)
study = optuna.create_study(direction='minimize',)
study.optimize(obj_func, n_trials=5)

print(f"Best score: {study.best_value:5f}")
print(f"Best params: {study.best_params}")

best_model = SVC(**study.best_params, probability=True).fit(xtrain_sample.values, ytrain_sample.values.ravel())
model_performance, estimators = add_model_performance(model_name='SVC', clf=best_model)

display(model_performance)
# Out:
#   model_name  train_accuracy  test_accuracy  train_precision  test_precision  \
# 0        SVC           0.892          0.893            0.897           0.898
#
#    train_recall  test_recall  train_f1  test_f1  train_roc_auc  test_roc_auc  \
# 0          0.91        0.911     0.904    0.904          0.935         0.936
#
#    train_log_loss  test_log_loss
# 0           0.302          0.299

# %% [markdown]
# #### LightGBM Classifier

# %%
from lightgbm import LGBMClassifier
def objective(trial, xtrain, ytrain, kf):
    params = {
        'boosting_type': trial.suggest_categorical('boosting_type', ['gbdt']),
        'max_depth': trial.suggest_categorical('max_depth', [1, 2]),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1e0),
        'n_estimators': trial.suggest_int('n_estimators', 10, 3001, 10),
        'verbosity':-1
    }
    model = LGBMClassifier(**params)
    scores = cross_validate(model, xtrain, ytrain, cv=kf, scoring='neg_log_loss', n_jobs=-1)
    loss = -scores['test_score'].mean()
    return loss

kf = KFold(n_splits=3, shuffle=True, random_state=42)
obj_func = lambda trial: objective(trial, xtrain.values, ytrain.values.ravel(), kf)
study = optuna.create_study(direction='minimize',)
study.optimize(obj_func, n_trials=50)

print(f"Best score: {study.best_value:5f}")
print(f"Best params: {study.best_params}")

best_model = LGBMClassifier(**study.best_params).fit(xtrain.values, ytrain.values.ravel())
model_performance, estimators = add_model_performance(model_name='LGBMClassifier', clf=best_model, df=model_performance, model_dict=estimators)

display(model_performance)
# Out:
# Best score: 0.269692
# Best params: {'boosting_type': 'gbdt', 'max_depth': 2, 'learning_rate': 0.03408980842127418, 'n_estimators': 560}
# [LightGBM] [Info] Number of positive: 157075, number of negative: 125839
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001525 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 482
# [LightGBM] [Info] Number of data points in the train set: 282914, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.555204 -> initscore=0.221720
# [LightGBM] [Info] Start training from score 0.221720
#                model_name  train_accuracy  test_accuracy  train_precision  \
# 0      LogisticRegression           0.848          0.849            0.874
# 1  DecisionTreeClassifier           0.935          0.935            0.897
# 2  RandomForestClassifier           0.936          0.936            0.898
# 3           XGBClassifier           0.914          0.914            0.900
# 4    KNeighborsClassifier           1.000          0.907            1.000
# 5              StackingLR           0.934          0.934            0.898
# 6             StackingXGB           0.936          0.937            0.897
# 7          LGBMClassifier           0.910          0.910            0.900
#
#    test_precision  train_recall  test_recall  train_f1  test_f1  \
# 0           0.873         0.849        0.852     0.861    0.863
# 1           0.898         0.997        0.997     0.944    0.945
# 2           0.898         0.998        0.998     0.945    0.946
# 3           0.900         0.952        0.951     0.925    0.925
# 4           0.901         1.000        0.935     1.000    0.918
# 5           0.898         0.994        0.994     0.943    0.944
# 6           0.898         0.999        0.999     0.946    0.946
# 7           0.900         0.943        0.941     0.921    0.920
#
#    train_roc_auc  test_roc_auc  train_log_loss  test_log_loss
# 0          0.908         0.910           0.390          0.388
# 1          0.962         0.953           0.182          0.191
# 2          0.996         0.954           0.162          0.186
# 3          0.950         0.949           0.251          0.252
# 4          1.000         0.938           0.000          0.896
# 5          0.953         0.953           0.198          0.197
# 6          0.953         0.953           0.182          0.181
# 7          0.947         0.947           0.269          0.268

# %% [markdown]
# #### CatBoost Classifier

# %%
from catboost import CatBoostClassifier
def objective(trial, xtrain, ytrain, kf):
    params = {
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1e0),
        'depth': trial.suggest_categorical('depth', [1, 2]),
        'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 1e3),
        'model_size_reg': trial.suggest_loguniform('model_size_reg', 1e-3, 1e3),
        'verbose': 0
    }
    model = CatBoostClassifier(**params)
    scores = cross_validate(model, xtrain, ytrain, cv=kf, scoring='neg_log_loss', n_jobs=-1)
    loss = -scores['test_score'].mean()
    return loss

kf = KFold(n_splits=3, shuffle=True, random_state=42)
obj_func = lambda trial: objective(trial, xtrain.values, ytrain.values.ravel(), kf)
study = optuna.create_study(direction='minimize',)
study.optimize(obj_func, n_trials=50)

print(f"Best score: {study.best_value:5f}")
print(f"Best params: {study.best_params}")

best_model = CatBoostClassifier(**study.best_params).fit(xtrain.values, ytrain.values.ravel())
model_performance, estimators = add_model_performance(model_name='CatBoostClassifier', clf=best_model, df=model_performance, model_dict=estimators)

display(model_performance)
# Out:
# Best score: 0.353479
# Best params: {'learning_rate': 0.005395480987241722, 'depth': 1, 'l2_leaf_reg': 1.3946066306928457, 'model_size_reg': 76.11035091840746}
# 0:	learn: 0.6910423	total: 66.7ms	remaining: 1m 6s
# 1:	learn: 0.6889661	total: 76.6ms	remaining: 38.2s
# 2:	learn: 0.6869162	total: 85.9ms	remaining: 28.6s
# 3:	learn: 0.6848925	total: 95ms	remaining: 23.7s
# 4:	learn: 0.6828915	total: 109ms	remaining: 21.6s
# 5:	learn: 0.6809136	total: 119ms	remaining: 19.7s
# 6:	learn: 0.6789650	total: 128ms	remaining: 18.1s
# 7:	learn: 0.6770385	total: 137ms	remaining: 17s
# 8:	learn: 0.6751332	total: 146ms	remaining: 16.1s
# 9:	learn: 0.6732556	total: 156ms	remaining: 15.4s
# 10:	learn: 0.6713978	total: 165ms	remaining: 14.8s
# 11:	learn: 0.6695686	total: 174ms	remaining: 14.4s
# 12:	learn: 0.6677568	total: 185ms	remaining: 14.1s
# 13:	learn: 0.6659726	total: 195ms	remaining: 13.8s
# 14:	learn: 0.6642088	total: 205ms	remaining: 13.4s
# 15:	learn: 0.6624655	total: 214ms	remaining: 13.1s
# 16:	learn: 0.6607485	total: 223ms	remaining: 12.9s
# 17:	learn: 0.6590589	total: 232ms	remaining: 12.7s
# 18:	learn: 0.6573809	total: 241ms	remaining: 12.5s
# 19:	learn: 0.6557305	total: 251ms	remaining: 12.3s
# 20:	learn: 0.6540981	total: 286ms	remaining: 13.4s
# 21:	learn: 0.6524896	total: 306ms	remaining: 13.6s
# 22:	learn: 0.6508992	total: 318ms	remaining: 13.5s
# 23:	learn: 0.6493290	total: 329ms	remaining: 13.4s
# 24:	learn: 0.6480164	total: 342ms	remaining: 13.3s
# 25:	learn: 0.6464814	total: 353ms	remaining: 13.2s
# 26:	learn: 0.6449689	total: 364ms	remaining: 13.1s
# 27:	learn: 0.6434743	total: 376ms	remaining: 13s
# 28:	learn: 0.6420044	total: 387ms	remaining: 12.9s
# 29:	learn: 0.6405469	total: 398ms	remaining: 12.9s
# 30:	learn: 0.6391101	total: 409ms	remaining: 12.8s
# 31:	learn: 0.6376909	total: 420ms	remaining: 12.7s
# 32:	learn: 0.6364922	total: 431ms	remaining: 12.6s
# 33:	learn: 0.6351090	total: 443ms	remaining: 12.6s
# 34:	learn: 0.6337420	total: 454ms	remaining: 12.5s
# 35:	learn: 0.6325870	total: 463ms	remaining: 12.4s
# 36:	learn: 0.6312965	total: 472ms	remaining: 12.3s
# 37:	learn: 0.6299646	total: 482ms	remaining: 12.2s
# 38:	learn: 0.6286491	total: 491ms	remaining: 12.1s
# 39:	learn: 0.6273880	total: 501ms	remaining: 12s
# 40:	learn: 0.6262756	total: 510ms	remaining: 11.9s
# 41:	learn: 0.6251813	total: 520ms	remaining: 11.9s
# 42:	learn: 0.6240999	total: 529ms	remaining: 11.8s
# 43:	learn: 0.6228434	total: 538ms	remaining: 11.7s
# 44:	learn: 0.6216110	total: 547ms	remaining: 11.6s
# 45:	learn: 0.6203940	total: 557ms	remaining: 11.6s
# 46:	learn: 0.6193470	total: 566ms	remaining: 11.5s
# 47:	learn: 0.6181476	total: 575ms	remaining: 11.4s
# 48:	learn: 0.6169656	total: 585ms	remaining: 11.3s
# 49:	learn: 0.6159361	total: 594ms	remaining: 11.3s
# 50:	learn: 0.6147357	total: 603ms	remaining: 11.2s
# 51:	learn: 0.6135770	total: 612ms	remaining: 11.2s
# 52:	learn: 0.6123963	total: 621ms	remaining: 11.1s
# 53:	learn: 0.6112771	total: 631ms	remaining: 11.1s
# 54:	learn: 0.6101139	total: 640ms	remaining: 11s
# 55:	learn: 0.6091387	total: 649ms	remaining: 10.9s
# 56:	learn: 0.6080159	total: 659ms	remaining: 10.9s
# 57:	learn: 0.6070551	total: 668ms	remaining: 10.9s
# 58:	learn: 0.6059470	total: 678ms	remaining: 10.8s
# 59:	learn: 0.6048565	total: 687ms	remaining: 10.8s
# 60:	learn: 0.6037776	total: 697ms	remaining: 10.7s
# 61:	learn: 0.6026689	total: 706ms	remaining: 10.7s
# 62:	learn: 0.6014531	total: 716ms	remaining: 10.6s
# 63:	learn: 0.6003591	total: 725ms	remaining: 10.6s
# 64:	learn: 0.5992810	total: 736ms	remaining: 10.6s
# 65:	learn: 0.5980878	total: 745ms	remaining: 10.5s
# 66:	learn: 0.5970404	total: 755ms	remaining: 10.5s
# 67:	learn: 0.5960055	total: 768ms	remaining: 10.5s
# 68:	learn: 0.5949835	total: 781ms	remaining: 10.5s
# 69:	learn: 0.5940895	total: 792ms	remaining: 10.5s
# 70:	learn: 0.5929277	total: 804ms	remaining: 10.5s
# 71:	learn: 0.5917807	total: 817ms	remaining: 10.5s
# 72:	learn: 0.5907510	total: 828ms	remaining: 10.5s
# 73:	learn: 0.5897575	total: 840ms	remaining: 10.5s
# 74:	learn: 0.5888940	total: 851ms	remaining: 10.5s
# 75:	learn: 0.5877715	total: 863ms	remaining: 10.5s
# 76:	learn: 0.5867953	total: 874ms	remaining: 10.5s
# 77:	learn: 0.5858315	total: 886ms	remaining: 10.5s
# 78:	learn: 0.5849882	total: 900ms	remaining: 10.5s
# 79:	learn: 0.5840391	total: 915ms	remaining: 10.5s
# 80:	learn: 0.5829411	total: 930ms	remaining: 10.5s
# 81:	learn: 0.5819632	total: 941ms	remaining: 10.5s
# 82:	learn: 0.5811428	total: 953ms	remaining: 10.5s
# 83:	learn: 0.5800644	total: 963ms	remaining: 10.5s
# 84:	learn: 0.5791084	total: 973ms	remaining: 10.5s
# 85:	learn: 0.5781664	total: 983ms	remaining: 10.4s
# 86:	learn: 0.5771074	total: 993ms	remaining: 10.4s
# 87:	learn: 0.5761885	total: 1s	remaining: 10.4s
# 88:	learn: 0.5754039	total: 1.01s	remaining: 10.4s
# 89:	learn: 0.5743650	total: 1.02s	remaining: 10.3s
# 90:	learn: 0.5734516	total: 1.03s	remaining: 10.3s
# 91:	learn: 0.5725800	total: 1.04s	remaining: 10.3s
# 92:	learn: 0.5715593	total: 1.05s	remaining: 10.3s
# 93:	learn: 0.5706667	total: 1.06s	remaining: 10.2s
# 94:	learn: 0.5697820	total: 1.07s	remaining: 10.2s
# 95:	learn: 0.5689114	total: 1.08s	remaining: 10.2s
# 96:	learn: 0.5681646	total: 1.09s	remaining: 10.2s
# 97:	learn: 0.5671723	total: 1.1s	remaining: 10.1s
# 98:	learn: 0.5661938	total: 1.11s	remaining: 10.1s
# 99:	learn: 0.5654600	total: 1.12s	remaining: 10.1s
# 100:	learn: 0.5647334	total: 1.13s	remaining: 10.1s
# 101:	learn: 0.5638840	total: 1.14s	remaining: 10s
# 102:	learn: 0.5630478	total: 1.15s	remaining: 10s
# 103:	learn: 0.5622022	total: 1.16s	remaining: 10s
# 104:	learn: 0.5613779	total: 1.17s	remaining: 10s
# 105:	learn: 0.5604249	total: 1.19s	remaining: 10s
# 106:	learn: 0.5594832	total: 1.2s	remaining: 9.98s
# 107:	learn: 0.5586591	total: 1.21s	remaining: 9.96s
# 108:	learn: 0.5578779	total: 1.22s	remaining: 9.95s
# 109:	learn: 0.5570789	total: 1.23s	remaining: 9.93s
# 110:	learn: 0.5562668	total: 1.24s	remaining: 9.91s
# 111:	learn: 0.5553482	total: 1.25s	remaining: 9.9s
# 112:	learn: 0.5546690	total: 1.26s	remaining: 9.89s
# 113:	learn: 0.5537641	total: 1.27s	remaining: 9.87s
# 114:	learn: 0.5530993	total: 1.28s	remaining: 9.85s
# 115:	learn: 0.5522087	total: 1.29s	remaining: 9.84s
# 116:	learn: 0.5515513	total: 1.3s	remaining: 9.82s
# 117:	learn: 0.5507756	total: 1.31s	remaining: 9.81s
# 118:	learn: 0.5500104	total: 1.32s	remaining: 9.8s
# 119:	learn: 0.5492431	total: 1.33s	remaining: 9.79s
# 120:	learn: 0.5484896	total: 1.35s	remaining: 9.78s
# 121:	learn: 0.5477318	total: 1.36s	remaining: 9.78s
# 122:	learn: 0.5468647	total: 1.37s	remaining: 9.78s
# 123:	learn: 0.5462396	total: 1.38s	remaining: 9.77s
# 124:	learn: 0.5456193	total: 1.39s	remaining: 9.75s
# 125:	learn: 0.5447670	total: 1.4s	remaining: 9.73s
# 126:	learn: 0.5440382	total: 1.41s	remaining: 9.72s
# 127:	learn: 0.5431988	total: 1.42s	remaining: 9.69s
# 128:	learn: 0.5424672	total: 1.43s	remaining: 9.67s
# 129:	learn: 0.5417692	total: 1.44s	remaining: 9.64s
# 130:	learn: 0.5410684	total: 1.45s	remaining: 9.62s
# 131:	learn: 0.5403750	total: 1.46s	remaining: 9.6s
# 132:	learn: 0.5395552	total: 1.47s	remaining: 9.58s
# 133:	learn: 0.5389597	total: 1.48s	remaining: 9.56s
# 134:	learn: 0.5382554	total: 1.49s	remaining: 9.54s
# 135:	learn: 0.5375560	total: 1.5s	remaining: 9.53s
# 136:	learn: 0.5368593	total: 1.51s	remaining: 9.51s
# 137:	learn: 0.5361719	total: 1.52s	remaining: 9.49s
# 138:	learn: 0.5354848	total: 1.53s	remaining: 9.47s
# 139:	learn: 0.5348105	total: 1.54s	remaining: 9.45s
# 140:	learn: 0.5340134	total: 1.55s	remaining: 9.43s
# 141:	learn: 0.5332257	total: 1.56s	remaining: 9.41s
# 142:	learn: 0.5325646	total: 1.57s	remaining: 9.39s
# 143:	learn: 0.5318961	total: 1.58s	remaining: 9.38s
# 144:	learn: 0.5312259	total: 1.59s	remaining: 9.36s
# 145:	learn: 0.5305670	total: 1.6s	remaining: 9.34s
# 146:	learn: 0.5299299	total: 1.61s	remaining: 9.32s
# 147:	learn: 0.5291648	total: 1.61s	remaining: 9.3s
# 148:	learn: 0.5285174	total: 1.63s	remaining: 9.29s
# 149:	learn: 0.5278777	total: 1.64s	remaining: 9.27s
# 150:	learn: 0.5272544	total: 1.65s	remaining: 9.25s
# 151:	learn: 0.5266047	total: 1.66s	remaining: 9.23s
# 152:	learn: 0.5258545	total: 1.67s	remaining: 9.22s
# 153:	learn: 0.5252277	total: 1.68s	remaining: 9.2s
# 154:	learn: 0.5244895	total: 1.68s	remaining: 9.18s
# 155:	learn: 0.5239528	total: 1.69s	remaining: 9.16s
# 156:	learn: 0.5233359	total: 1.7s	remaining: 9.14s
# 157:	learn: 0.5227072	total: 1.71s	remaining: 9.13s
# 158:	learn: 0.5220812	total: 1.72s	remaining: 9.11s
# 159:	learn: 0.5214600	total: 1.73s	remaining: 9.1s
# 160:	learn: 0.5209395	total: 1.74s	remaining: 9.09s
# 161:	learn: 0.5202190	total: 1.75s	remaining: 9.07s
# 162:	learn: 0.5196088	total: 1.76s	remaining: 9.06s
# 163:	learn: 0.5190087	total: 1.77s	remaining: 9.05s
# 164:	learn: 0.5184020	total: 1.79s	remaining: 9.05s
# 165:	learn: 0.5178017	total: 1.8s	remaining: 9.05s
# 166:	learn: 0.5171954	total: 1.81s	remaining: 9.05s
# 167:	learn: 0.5164893	total: 1.83s	remaining: 9.06s
# 168:	learn: 0.5158944	total: 1.84s	remaining: 9.06s
# 169:	learn: 0.5153925	total: 1.86s	remaining: 9.07s
# 170:	learn: 0.5148047	total: 1.87s	remaining: 9.08s
# 171:	learn: 0.5142213	total: 1.89s	remaining: 9.08s
# 172:	learn: 0.5136424	total: 1.9s	remaining: 9.08s
# 173:	learn: 0.5130647	total: 1.91s	remaining: 9.09s
# 174:	learn: 0.5124951	total: 1.93s	remaining: 9.08s
# 175:	learn: 0.5119147	total: 1.94s	remaining: 9.09s
# 176:	learn: 0.5112269	total: 1.95s	remaining: 9.08s
# 177:	learn: 0.5107399	total: 1.96s	remaining: 9.07s
# 178:	learn: 0.5102596	total: 1.98s	remaining: 9.06s
# 179:	learn: 0.5095846	total: 1.99s	remaining: 9.04s
# 180:	learn: 0.5090151	total: 2s	remaining: 9.04s
# 181:	learn: 0.5084476	total: 2.01s	remaining: 9.03s
# 182:	learn: 0.5077832	total: 2.02s	remaining: 9.02s
# 183:	learn: 0.5072236	total: 2.03s	remaining: 9.01s
# 184:	learn: 0.5065722	total: 2.04s	remaining: 9s
# 185:	learn: 0.5060183	total: 2.05s	remaining: 8.98s
# 186:	learn: 0.5055538	total: 2.06s	remaining: 8.97s
# 187:	learn: 0.5050040	total: 2.07s	remaining: 8.96s
# 188:	learn: 0.5043649	total: 2.08s	remaining: 8.94s
# 189:	learn: 0.5039070	total: 2.09s	remaining: 8.92s
# 190:	learn: 0.5033539	total: 2.1s	remaining: 8.91s
# 191:	learn: 0.5028085	total: 2.11s	remaining: 8.89s
# 192:	learn: 0.5022697	total: 2.12s	remaining: 8.88s
# 193:	learn: 0.5017312	total: 2.13s	remaining: 8.87s
# 194:	learn: 0.5011937	total: 2.15s	remaining: 8.86s
# 195:	learn: 0.5006649	total: 2.16s	remaining: 8.85s
# 196:	learn: 0.5001353	total: 2.17s	remaining: 8.83s
# 197:	learn: 0.4996002	total: 2.18s	remaining: 8.81s
# 198:	learn: 0.4991621	total: 2.19s	remaining: 8.8s
# 199:	learn: 0.4985395	total: 2.2s	remaining: 8.78s
# 200:	learn: 0.4980177	total: 2.21s	remaining: 8.77s
# 201:	learn: 0.4975043	total: 2.22s	remaining: 8.76s
# 202:	learn: 0.4969811	total: 2.23s	remaining: 8.74s
# 203:	learn: 0.4964643	total: 2.24s	remaining: 8.73s
# 204:	learn: 0.4958539	total: 2.25s	remaining: 8.71s
# 205:	learn: 0.4953407	total: 2.26s	remaining: 8.7s
# 206:	learn: 0.4948266	total: 2.27s	remaining: 8.69s
# 207:	learn: 0.4942278	total: 2.28s	remaining: 8.67s
# 208:	learn: 0.4937248	total: 2.29s	remaining: 8.66s
# 209:	learn: 0.4932183	total: 2.3s	remaining: 8.65s
# 210:	learn: 0.4927121	total: 2.31s	remaining: 8.64s
# 211:	learn: 0.4921251	total: 2.32s	remaining: 8.63s
# 212:	learn: 0.4916290	total: 2.33s	remaining: 8.61s
# 213:	learn: 0.4912165	total: 2.34s	remaining: 8.6s
# 214:	learn: 0.4907206	total: 2.35s	remaining: 8.59s
# 215:	learn: 0.4902295	total: 2.36s	remaining: 8.57s
# 216:	learn: 0.4897311	total: 2.37s	remaining: 8.56s
# 217:	learn: 0.4892471	total: 2.38s	remaining: 8.54s
# 218:	learn: 0.4887601	total: 2.39s	remaining: 8.53s
# 219:	learn: 0.4882716	total: 2.4s	remaining: 8.51s
# 220:	learn: 0.4877908	total: 2.41s	remaining: 8.5s
# 221:	learn: 0.4873113	total: 2.42s	remaining: 8.49s
# 222:	learn: 0.4868290	total: 2.43s	remaining: 8.47s
# 223:	learn: 0.4863559	total: 2.44s	remaining: 8.46s
# 224:	learn: 0.4858828	total: 2.45s	remaining: 8.45s
# 225:	learn: 0.4854118	total: 2.46s	remaining: 8.43s
# 226:	learn: 0.4848427	total: 2.47s	remaining: 8.42s
# 227:	learn: 0.4843743	total: 2.48s	remaining: 8.4s
# 228:	learn: 0.4838161	total: 2.49s	remaining: 8.39s
# 229:	learn: 0.4833521	total: 2.5s	remaining: 8.38s
# 230:	learn: 0.4828017	total: 2.51s	remaining: 8.36s
# 231:	learn: 0.4824167	total: 2.52s	remaining: 8.35s
# 232:	learn: 0.4819525	total: 2.53s	remaining: 8.33s
# 233:	learn: 0.4814939	total: 2.54s	remaining: 8.32s
# 234:	learn: 0.4810379	total: 2.55s	remaining: 8.31s
# 235:	learn: 0.4805839	total: 2.56s	remaining: 8.29s
# 236:	learn: 0.4800441	total: 2.57s	remaining: 8.28s
# 237:	learn: 0.4795938	total: 2.58s	remaining: 8.27s
# 238:	learn: 0.4791444	total: 2.59s	remaining: 8.25s
# 239:	learn: 0.4786933	total: 2.6s	remaining: 8.24s
# 240:	learn: 0.4782498	total: 2.62s	remaining: 8.23s
# 241:	learn: 0.4778091	total: 2.63s	remaining: 8.22s
# 242:	learn: 0.4773657	total: 2.64s	remaining: 8.23s
# 243:	learn: 0.4769221	total: 2.65s	remaining: 8.21s
# 244:	learn: 0.4763974	total: 2.66s	remaining: 8.21s
# 245:	learn: 0.4758786	total: 2.67s	remaining: 8.2s
# 246:	learn: 0.4754417	total: 2.69s	remaining: 8.19s
# 247:	learn: 0.4750043	total: 2.69s	remaining: 8.17s
# 248:	learn: 0.4745708	total: 2.71s	remaining: 8.16s
# 249:	learn: 0.4742109	total: 2.71s	remaining: 8.14s
# 250:	learn: 0.4738560	total: 2.72s	remaining: 8.13s
# 251:	learn: 0.4734301	total: 2.73s	remaining: 8.12s
# 252:	learn: 0.4730111	total: 2.74s	remaining: 8.1s
# 253:	learn: 0.4725829	total: 2.75s	remaining: 8.09s
# 254:	learn: 0.4720773	total: 2.76s	remaining: 8.08s
# 255:	learn: 0.4716512	total: 2.77s	remaining: 8.06s
# 256:	learn: 0.4712388	total: 2.79s	remaining: 8.05s
# 257:	learn: 0.4707397	total: 2.79s	remaining: 8.04s
# 258:	learn: 0.4703221	total: 2.81s	remaining: 8.03s
# 259:	learn: 0.4699045	total: 2.82s	remaining: 8.02s
# 260:	learn: 0.4694163	total: 2.83s	remaining: 8s
# 261:	learn: 0.4689979	total: 2.84s	remaining: 7.99s
# 262:	learn: 0.4685850	total: 2.85s	remaining: 7.98s
# 263:	learn: 0.4681739	total: 2.86s	remaining: 7.97s
# 264:	learn: 0.4678364	total: 2.87s	remaining: 7.95s
# 265:	learn: 0.4674452	total: 2.88s	remaining: 7.94s
# 266:	learn: 0.4670371	total: 2.89s	remaining: 7.93s
# 267:	learn: 0.4665598	total: 2.9s	remaining: 7.92s
# 268:	learn: 0.4661556	total: 2.91s	remaining: 7.9s
# 269:	learn: 0.4657538	total: 2.92s	remaining: 7.89s
# 270:	learn: 0.4653597	total: 2.93s	remaining: 7.88s
# 271:	learn: 0.4648886	total: 2.94s	remaining: 7.87s
# 272:	learn: 0.4644982	total: 2.95s	remaining: 7.87s
# 273:	learn: 0.4641017	total: 2.97s	remaining: 7.86s
# 274:	learn: 0.4637080	total: 2.98s	remaining: 7.85s
# 275:	learn: 0.4633238	total: 2.99s	remaining: 7.84s
# 276:	learn: 0.4629297	total: 3s	remaining: 7.82s
# 277:	learn: 0.4625400	total: 3.01s	remaining: 7.81s
# 278:	learn: 0.4621532	total: 3.02s	remaining: 7.79s
# 279:	learn: 0.4618348	total: 3.02s	remaining: 7.78s
# 280:	learn: 0.4614471	total: 3.04s	remaining: 7.77s
# 281:	learn: 0.4609895	total: 3.05s	remaining: 7.76s
# 282:	learn: 0.4606080	total: 3.06s	remaining: 7.75s
# 283:	learn: 0.4602364	total: 3.07s	remaining: 7.74s
# 284:	learn: 0.4598604	total: 3.08s	remaining: 7.72s
# 285:	learn: 0.4594925	total: 3.09s	remaining: 7.71s
# 286:	learn: 0.4591148	total: 3.1s	remaining: 7.7s
# 287:	learn: 0.4586664	total: 3.11s	remaining: 7.68s
# 288:	learn: 0.4582880	total: 3.12s	remaining: 7.67s
# 289:	learn: 0.4579124	total: 3.13s	remaining: 7.66s
# 290:	learn: 0.4575427	total: 3.14s	remaining: 7.65s
# 291:	learn: 0.4571742	total: 3.15s	remaining: 7.64s
# 292:	learn: 0.4568089	total: 3.16s	remaining: 7.63s
# 293:	learn: 0.4563672	total: 3.17s	remaining: 7.62s
# 294:	learn: 0.4560054	total: 3.18s	remaining: 7.61s
# 295:	learn: 0.4556443	total: 3.19s	remaining: 7.59s
# 296:	learn: 0.4552869	total: 3.2s	remaining: 7.58s
# 297:	learn: 0.4548554	total: 3.21s	remaining: 7.57s
# 298:	learn: 0.4544916	total: 3.22s	remaining: 7.56s
# 299:	learn: 0.4541402	total: 3.23s	remaining: 7.55s
# 300:	learn: 0.4537148	total: 3.25s	remaining: 7.54s
# 301:	learn: 0.4534228	total: 3.25s	remaining: 7.53s
# 302:	learn: 0.4530656	total: 3.27s	remaining: 7.51s
# 303:	learn: 0.4527079	total: 3.27s	remaining: 7.5s
# 304:	learn: 0.4523563	total: 3.29s	remaining: 7.49s
# 305:	learn: 0.4520671	total: 3.29s	remaining: 7.47s
# 306:	learn: 0.4517170	total: 3.3s	remaining: 7.46s
# 307:	learn: 0.4514331	total: 3.31s	remaining: 7.45s
# 308:	learn: 0.4510142	total: 3.32s	remaining: 7.43s
# 309:	learn: 0.4506622	total: 3.33s	remaining: 7.42s
# 310:	learn: 0.4503193	total: 3.34s	remaining: 7.41s
# 311:	learn: 0.4500387	total: 3.35s	remaining: 7.39s
# 312:	learn: 0.4496281	total: 3.36s	remaining: 7.38s
# 313:	learn: 0.4492809	total: 3.37s	remaining: 7.37s
# 314:	learn: 0.4489369	total: 3.38s	remaining: 7.35s
# 315:	learn: 0.4485970	total: 3.39s	remaining: 7.34s
# 316:	learn: 0.4482549	total: 3.4s	remaining: 7.33s
# 317:	learn: 0.4479172	total: 3.41s	remaining: 7.32s
# 318:	learn: 0.4475891	total: 3.42s	remaining: 7.31s
# 319:	learn: 0.4471862	total: 3.44s	remaining: 7.31s
# 320:	learn: 0.4468508	total: 3.45s	remaining: 7.3s
# 321:	learn: 0.4465178	total: 3.46s	remaining: 7.29s
# 322:	learn: 0.4461872	total: 3.47s	remaining: 7.28s
# 323:	learn: 0.4458645	total: 3.48s	remaining: 7.27s
# 324:	learn: 0.4455354	total: 3.49s	remaining: 7.25s
# 325:	learn: 0.4452099	total: 3.5s	remaining: 7.24s
# 326:	learn: 0.4448156	total: 3.51s	remaining: 7.23s
# 327:	learn: 0.4444886	total: 3.52s	remaining: 7.22s
# 328:	learn: 0.4441672	total: 3.53s	remaining: 7.21s
# 329:	learn: 0.4438460	total: 3.54s	remaining: 7.2s
# 330:	learn: 0.4434592	total: 3.55s	remaining: 7.18s
# 331:	learn: 0.4431423	total: 3.56s	remaining: 7.17s
# 332:	learn: 0.4428297	total: 3.57s	remaining: 7.16s
# 333:	learn: 0.4425688	total: 3.58s	remaining: 7.14s
# 334:	learn: 0.4423143	total: 3.59s	remaining: 7.13s
# 335:	learn: 0.4419979	total: 3.61s	remaining: 7.13s
# 336:	learn: 0.4416764	total: 3.62s	remaining: 7.13s
# 337:	learn: 0.4413735	total: 3.65s	remaining: 7.14s
# 338:	learn: 0.4410566	total: 3.66s	remaining: 7.14s
# 339:	learn: 0.4407476	total: 3.67s	remaining: 7.13s
# 340:	learn: 0.4403709	total: 3.68s	remaining: 7.12s
# 341:	learn: 0.4399955	total: 3.69s	remaining: 7.11s
# 342:	learn: 0.4396874	total: 3.7s	remaining: 7.09s
# 343:	learn: 0.4393909	total: 3.71s	remaining: 7.08s
# 344:	learn: 0.4390234	total: 3.72s	remaining: 7.07s
# 345:	learn: 0.4387775	total: 3.73s	remaining: 7.05s
# 346:	learn: 0.4384691	total: 3.74s	remaining: 7.04s
# 347:	learn: 0.4381656	total: 3.75s	remaining: 7.03s
# 348:	learn: 0.4378765	total: 3.76s	remaining: 7.01s
# 349:	learn: 0.4376372	total: 3.77s	remaining: 7s
# 350:	learn: 0.4373355	total: 3.78s	remaining: 6.99s
# 351:	learn: 0.4370345	total: 3.79s	remaining: 6.97s
# 352:	learn: 0.4367301	total: 3.8s	remaining: 6.96s
# 353:	learn: 0.4363714	total: 3.81s	remaining: 6.95s
# 354:	learn: 0.4360742	total: 3.82s	remaining: 6.93s
# 355:	learn: 0.4357756	total: 3.83s	remaining: 6.92s
# 356:	learn: 0.4354850	total: 3.83s	remaining: 6.91s
# 357:	learn: 0.4351891	total: 3.85s	remaining: 6.89s
# 358:	learn: 0.4348359	total: 3.85s	remaining: 6.88s
# 359:	learn: 0.4345444	total: 3.87s	remaining: 6.87s
# 360:	learn: 0.4342642	total: 3.88s	remaining: 6.86s
# 361:	learn: 0.4339776	total: 3.88s	remaining: 6.85s
# 362:	learn: 0.4336885	total: 3.9s	remaining: 6.83s
# 363:	learn: 0.4333987	total: 3.9s	remaining: 6.82s
# 364:	learn: 0.4330525	total: 3.91s	remaining: 6.81s
# 365:	learn: 0.4327797	total: 3.92s	remaining: 6.8s
# 366:	learn: 0.4324954	total: 3.93s	remaining: 6.78s
# 367:	learn: 0.4321544	total: 3.94s	remaining: 6.77s
# 368:	learn: 0.4318729	total: 3.95s	remaining: 6.76s
# 369:	learn: 0.4316038	total: 3.96s	remaining: 6.75s
# 370:	learn: 0.4313214	total: 3.97s	remaining: 6.73s
# 371:	learn: 0.4310989	total: 3.98s	remaining: 6.72s
# 372:	learn: 0.4308191	total: 3.99s	remaining: 6.71s
# 373:	learn: 0.4305426	total: 4s	remaining: 6.69s
# 374:	learn: 0.4302647	total: 4.01s	remaining: 6.68s
# 375:	learn: 0.4299872	total: 4.02s	remaining: 6.67s
# 376:	learn: 0.4297141	total: 4.03s	remaining: 6.66s
# 377:	learn: 0.4293810	total: 4.04s	remaining: 6.64s
# 378:	learn: 0.4291093	total: 4.05s	remaining: 6.63s
# 379:	learn: 0.4288892	total: 4.06s	remaining: 6.62s
# 380:	learn: 0.4286744	total: 4.07s	remaining: 6.6s
# 381:	learn: 0.4283458	total: 4.08s	remaining: 6.59s
# 382:	learn: 0.4280785	total: 4.08s	remaining: 6.58s
# 383:	learn: 0.4278089	total: 4.09s	remaining: 6.57s
# 384:	learn: 0.4274861	total: 4.1s	remaining: 6.55s
# 385:	learn: 0.4272307	total: 4.11s	remaining: 6.54s
# 386:	learn: 0.4269730	total: 4.12s	remaining: 6.53s
# 387:	learn: 0.4267132	total: 4.13s	remaining: 6.52s
# 388:	learn: 0.4263956	total: 4.14s	remaining: 6.51s
# 389:	learn: 0.4261302	total: 4.15s	remaining: 6.49s
# 390:	learn: 0.4258712	total: 4.16s	remaining: 6.48s
# 391:	learn: 0.4256018	total: 4.17s	remaining: 6.47s
# 392:	learn: 0.4253376	total: 4.18s	remaining: 6.46s
# 393:	learn: 0.4250828	total: 4.19s	remaining: 6.44s
# 394:	learn: 0.4248328	total: 4.2s	remaining: 6.43s
# 395:	learn: 0.4245803	total: 4.21s	remaining: 6.42s
# 396:	learn: 0.4242685	total: 4.22s	remaining: 6.41s
# 397:	learn: 0.4240088	total: 4.23s	remaining: 6.4s
# 398:	learn: 0.4237638	total: 4.24s	remaining: 6.38s
# 399:	learn: 0.4234565	total: 4.25s	remaining: 6.37s
# 400:	learn: 0.4232007	total: 4.26s	remaining: 6.36s
# 401:	learn: 0.4228979	total: 4.27s	remaining: 6.35s
# 402:	learn: 0.4226435	total: 4.28s	remaining: 6.34s
# 403:	learn: 0.4224410	total: 4.29s	remaining: 6.33s
# 404:	learn: 0.4221899	total: 4.3s	remaining: 6.31s
# 405:	learn: 0.4219489	total: 4.3s	remaining: 6.3s
# 406:	learn: 0.4217100	total: 4.31s	remaining: 6.29s
# 407:	learn: 0.4214594	total: 4.32s	remaining: 6.27s
# 408:	learn: 0.4212121	total: 4.33s	remaining: 6.26s
# 409:	learn: 0.4209651	total: 4.34s	remaining: 6.25s
# 410:	learn: 0.4206698	total: 4.35s	remaining: 6.24s
# 411:	learn: 0.4204239	total: 4.36s	remaining: 6.22s
# 412:	learn: 0.4201330	total: 4.37s	remaining: 6.21s
# 413:	learn: 0.4198441	total: 4.38s	remaining: 6.2s
# 414:	learn: 0.4196084	total: 4.39s	remaining: 6.19s
# 415:	learn: 0.4193244	total: 4.4s	remaining: 6.18s
# 416:	learn: 0.4190847	total: 4.41s	remaining: 6.17s
# 417:	learn: 0.4188423	total: 4.42s	remaining: 6.16s
# 418:	learn: 0.4186495	total: 4.43s	remaining: 6.15s
# 419:	learn: 0.4184111	total: 4.44s	remaining: 6.13s
# 420:	learn: 0.4181709	total: 4.45s	remaining: 6.12s
# 421:	learn: 0.4179415	total: 4.46s	remaining: 6.11s
# 422:	learn: 0.4177139	total: 4.47s	remaining: 6.1s
# 423:	learn: 0.4174890	total: 4.48s	remaining: 6.09s
# 424:	learn: 0.4173029	total: 4.49s	remaining: 6.08s
# 425:	learn: 0.4170668	total: 4.5s	remaining: 6.06s
# 426:	learn: 0.4168458	total: 4.51s	remaining: 6.05s
# 427:	learn: 0.4166208	total: 4.52s	remaining: 6.04s
# 428:	learn: 0.4163886	total: 4.53s	remaining: 6.03s
# 429:	learn: 0.4162062	total: 4.54s	remaining: 6.01s
# 430:	learn: 0.4159844	total: 4.55s	remaining: 6s
# 431:	learn: 0.4157528	total: 4.55s	remaining: 5.99s
# 432:	learn: 0.4155264	total: 4.57s	remaining: 5.98s
# 433:	learn: 0.4152482	total: 4.58s	remaining: 5.97s
# 434:	learn: 0.4150247	total: 4.58s	remaining: 5.95s
# 435:	learn: 0.4147950	total: 4.59s	remaining: 5.94s
# 436:	learn: 0.4145671	total: 4.6s	remaining: 5.93s
# 437:	learn: 0.4143421	total: 4.61s	remaining: 5.92s
# 438:	learn: 0.4140706	total: 4.62s	remaining: 5.91s
# 439:	learn: 0.4138021	total: 4.63s	remaining: 5.89s
# 440:	learn: 0.4135825	total: 4.64s	remaining: 5.88s
# 441:	learn: 0.4134057	total: 4.65s	remaining: 5.87s
# 442:	learn: 0.4132307	total: 4.66s	remaining: 5.86s
# 443:	learn: 0.4130054	total: 4.67s	remaining: 5.85s
# 444:	learn: 0.4127842	total: 4.68s	remaining: 5.83s
# 445:	learn: 0.4125682	total: 4.69s	remaining: 5.82s
# 446:	learn: 0.4123595	total: 4.7s	remaining: 5.81s
# 447:	learn: 0.4121402	total: 4.71s	remaining: 5.8s
# 448:	learn: 0.4119229	total: 4.72s	remaining: 5.79s
# 449:	learn: 0.4117180	total: 4.72s	remaining: 5.78s
# 450:	learn: 0.4114548	total: 4.74s	remaining: 5.76s
# 451:	learn: 0.4112373	total: 4.74s	remaining: 5.75s
# 452:	learn: 0.4110686	total: 4.75s	remaining: 5.74s
# 453:	learn: 0.4108684	total: 4.76s	remaining: 5.73s
# 454:	learn: 0.4106579	total: 4.77s	remaining: 5.71s
# 455:	learn: 0.4104438	total: 4.78s	remaining: 5.7s
# 456:	learn: 0.4101864	total: 4.79s	remaining: 5.69s
# 457:	learn: 0.4099321	total: 4.8s	remaining: 5.68s
# 458:	learn: 0.4096806	total: 4.81s	remaining: 5.67s
# 459:	learn: 0.4094830	total: 4.82s	remaining: 5.66s
# 460:	learn: 0.4092706	total: 4.83s	remaining: 5.64s
# 461:	learn: 0.4090593	total: 4.84s	remaining: 5.63s
# 462:	learn: 0.4088507	total: 4.85s	remaining: 5.62s
# 463:	learn: 0.4086455	total: 4.86s	remaining: 5.61s
# 464:	learn: 0.4084415	total: 4.87s	remaining: 5.6s
# 465:	learn: 0.4082349	total: 4.88s	remaining: 5.59s
# 466:	learn: 0.4080280	total: 4.88s	remaining: 5.58s
# 467:	learn: 0.4077806	total: 4.89s	remaining: 5.56s
# 468:	learn: 0.4075892	total: 4.9s	remaining: 5.55s
# 469:	learn: 0.4073980	total: 4.91s	remaining: 5.54s
# 470:	learn: 0.4071962	total: 4.92s	remaining: 5.53s
# 471:	learn: 0.4070083	total: 4.93s	remaining: 5.52s
# 472:	learn: 0.4068031	total: 4.94s	remaining: 5.5s
# 473:	learn: 0.4066030	total: 4.95s	remaining: 5.49s
# 474:	learn: 0.4064122	total: 4.96s	remaining: 5.48s
# 475:	learn: 0.4061705	total: 4.97s	remaining: 5.47s
# 476:	learn: 0.4059683	total: 4.98s	remaining: 5.46s
# 477:	learn: 0.4057698	total: 4.99s	remaining: 5.45s
# 478:	learn: 0.4055703	total: 5s	remaining: 5.44s
# 479:	learn: 0.4053346	total: 5.01s	remaining: 5.43s
# 480:	learn: 0.4051398	total: 5.02s	remaining: 5.42s
# 481:	learn: 0.4049440	total: 5.03s	remaining: 5.41s
# 482:	learn: 0.4047504	total: 5.04s	remaining: 5.4s
# 483:	learn: 0.4045562	total: 5.05s	remaining: 5.38s
# 484:	learn: 0.4043721	total: 5.06s	remaining: 5.37s
# 485:	learn: 0.4041811	total: 5.07s	remaining: 5.36s
# 486:	learn: 0.4040006	total: 5.08s	remaining: 5.35s
# 487:	learn: 0.4037674	total: 5.09s	remaining: 5.34s
# 488:	learn: 0.4035793	total: 5.1s	remaining: 5.33s
# 489:	learn: 0.4033485	total: 5.11s	remaining: 5.32s
# 490:	learn: 0.4031689	total: 5.12s	remaining: 5.3s
# 491:	learn: 0.4029839	total: 5.13s	remaining: 5.29s
# 492:	learn: 0.4027572	total: 5.13s	remaining: 5.28s
# 493:	learn: 0.4025330	total: 5.14s	remaining: 5.27s
# 494:	learn: 0.4023546	total: 5.15s	remaining: 5.26s
# 495:	learn: 0.4021636	total: 5.16s	remaining: 5.25s
# 496:	learn: 0.4019751	total: 5.17s	remaining: 5.23s
# 497:	learn: 0.4018002	total: 5.18s	remaining: 5.22s
# 498:	learn: 0.4016148	total: 5.19s	remaining: 5.21s
# 499:	learn: 0.4014678	total: 5.2s	remaining: 5.2s
# 500:	learn: 0.4012835	total: 5.21s	remaining: 5.19s
# 501:	learn: 0.4011112	total: 5.22s	remaining: 5.18s
# 502:	learn: 0.4008919	total: 5.23s	remaining: 5.17s
# 503:	learn: 0.4007096	total: 5.24s	remaining: 5.15s
# 504:	learn: 0.4005239	total: 5.25s	remaining: 5.14s
# 505:	learn: 0.4003085	total: 5.26s	remaining: 5.13s
# 506:	learn: 0.4001664	total: 5.27s	remaining: 5.12s
# 507:	learn: 0.3999845	total: 5.28s	remaining: 5.11s
# 508:	learn: 0.3998165	total: 5.29s	remaining: 5.1s
# 509:	learn: 0.3996388	total: 5.29s	remaining: 5.09s
# 510:	learn: 0.3994256	total: 5.3s	remaining: 5.08s
# 511:	learn: 0.3992474	total: 5.31s	remaining: 5.06s
# 512:	learn: 0.3991200	total: 5.32s	remaining: 5.05s
# 513:	learn: 0.3989418	total: 5.33s	remaining: 5.04s
# 514:	learn: 0.3987658	total: 5.34s	remaining: 5.03s
# 515:	learn: 0.3985554	total: 5.35s	remaining: 5.02s
# 516:	learn: 0.3983807	total: 5.36s	remaining: 5.01s
# 517:	learn: 0.3982032	total: 5.37s	remaining: 5s
# 518:	learn: 0.3980321	total: 5.38s	remaining: 4.98s
# 519:	learn: 0.3978685	total: 5.39s	remaining: 4.97s
# 520:	learn: 0.3977070	total: 5.4s	remaining: 4.96s
# 521:	learn: 0.3975364	total: 5.41s	remaining: 4.95s
# 522:	learn: 0.3973634	total: 5.42s	remaining: 4.94s
# 523:	learn: 0.3971941	total: 5.42s	remaining: 4.93s
# 524:	learn: 0.3970344	total: 5.43s	remaining: 4.92s
# 525:	learn: 0.3968680	total: 5.44s	remaining: 4.91s
# 526:	learn: 0.3967039	total: 5.45s	remaining: 4.89s
# 527:	learn: 0.3964975	total: 5.46s	remaining: 4.88s
# 528:	learn: 0.3963269	total: 5.47s	remaining: 4.87s
# 529:	learn: 0.3961945	total: 5.48s	remaining: 4.86s
# 530:	learn: 0.3960330	total: 5.49s	remaining: 4.85s
# 531:	learn: 0.3958300	total: 5.5s	remaining: 4.84s
# 532:	learn: 0.3956619	total: 5.51s	remaining: 4.83s
# 533:	learn: 0.3954925	total: 5.52s	remaining: 4.82s
# 534:	learn: 0.3953267	total: 5.53s	remaining: 4.8s
# 535:	learn: 0.3952081	total: 5.54s	remaining: 4.79s
# 536:	learn: 0.3950536	total: 5.55s	remaining: 4.78s
# 537:	learn: 0.3948986	total: 5.56s	remaining: 4.77s
# 538:	learn: 0.3947360	total: 5.57s	remaining: 4.76s
# 539:	learn: 0.3945702	total: 5.57s	remaining: 4.75s
# 540:	learn: 0.3944406	total: 5.58s	remaining: 4.74s
# 541:	learn: 0.3942780	total: 5.59s	remaining: 4.73s
# 542:	learn: 0.3940803	total: 5.6s	remaining: 4.71s
# 543:	learn: 0.3939176	total: 5.61s	remaining: 4.7s
# 544:	learn: 0.3937567	total: 5.62s	remaining: 4.69s
# 545:	learn: 0.3935601	total: 5.63s	remaining: 4.68s
# 546:	learn: 0.3934046	total: 5.64s	remaining: 4.67s
# 547:	learn: 0.3932458	total: 5.65s	remaining: 4.66s
# 548:	learn: 0.3930921	total: 5.66s	remaining: 4.65s
# 549:	learn: 0.3928975	total: 5.67s	remaining: 4.64s
# 550:	learn: 0.3927485	total: 5.68s	remaining: 4.63s
# 551:	learn: 0.3925963	total: 5.69s	remaining: 4.62s
# 552:	learn: 0.3924044	total: 5.7s	remaining: 4.61s
# 553:	learn: 0.3922495	total: 5.71s	remaining: 4.59s
# 554:	learn: 0.3920933	total: 5.71s	remaining: 4.58s
# 555:	learn: 0.3919703	total: 5.72s	remaining: 4.57s
# 556:	learn: 0.3918136	total: 5.73s	remaining: 4.56s
# 557:	learn: 0.3917001	total: 5.74s	remaining: 4.55s
# 558:	learn: 0.3915441	total: 5.75s	remaining: 4.54s
# 559:	learn: 0.3913924	total: 5.76s	remaining: 4.53s
# 560:	learn: 0.3912044	total: 5.77s	remaining: 4.51s
# 561:	learn: 0.3910540	total: 5.78s	remaining: 4.5s
# 562:	learn: 0.3909060	total: 5.79s	remaining: 4.49s
# 563:	learn: 0.3907590	total: 5.8s	remaining: 4.48s
# 564:	learn: 0.3906138	total: 5.81s	remaining: 4.47s
# 565:	learn: 0.3905037	total: 5.82s	remaining: 4.46s
# 566:	learn: 0.3903584	total: 5.82s	remaining: 4.45s
# 567:	learn: 0.3902399	total: 5.83s	remaining: 4.44s
# 568:	learn: 0.3900621	total: 5.84s	remaining: 4.42s
# 569:	learn: 0.3899452	total: 5.85s	remaining: 4.41s
# 570:	learn: 0.3897704	total: 5.86s	remaining: 4.4s
# 571:	learn: 0.3896221	total: 5.87s	remaining: 4.39s
# 572:	learn: 0.3894441	total: 5.88s	remaining: 4.38s
# 573:	learn: 0.3893005	total: 5.89s	remaining: 4.37s
# 574:	learn: 0.3891505	total: 5.9s	remaining: 4.36s
# 575:	learn: 0.3890116	total: 5.91s	remaining: 4.35s
# 576:	learn: 0.3888617	total: 5.92s	remaining: 4.34s
# 577:	learn: 0.3887479	total: 5.92s	remaining: 4.33s
# 578:	learn: 0.3886002	total: 5.93s	remaining: 4.31s
# 579:	learn: 0.3884315	total: 5.94s	remaining: 4.3s
# 580:	learn: 0.3882850	total: 5.95s	remaining: 4.29s
# 581:	learn: 0.3881507	total: 5.96s	remaining: 4.28s
# 582:	learn: 0.3880058	total: 5.97s	remaining: 4.27s
# 583:	learn: 0.3878374	total: 5.98s	remaining: 4.26s
# 584:	learn: 0.3877035	total: 5.99s	remaining: 4.25s
# 585:	learn: 0.3875646	total: 5.99s	remaining: 4.24s
# 586:	learn: 0.3874217	total: 6s	remaining: 4.22s
# 587:	learn: 0.3872821	total: 6.01s	remaining: 4.21s
# 588:	learn: 0.3871390	total: 6.02s	remaining: 4.2s
# 589:	learn: 0.3869735	total: 6.03s	remaining: 4.19s
# 590:	learn: 0.3868401	total: 6.04s	remaining: 4.18s
# 591:	learn: 0.3867000	total: 6.05s	remaining: 4.17s
# 592:	learn: 0.3865615	total: 6.06s	remaining: 4.16s
# 593:	learn: 0.3864518	total: 6.07s	remaining: 4.15s
# 594:	learn: 0.3863223	total: 6.08s	remaining: 4.13s
# 595:	learn: 0.3861836	total: 6.08s	remaining: 4.12s
# 596:	learn: 0.3860202	total: 6.09s	remaining: 4.11s
# 597:	learn: 0.3858854	total: 6.1s	remaining: 4.1s
# 598:	learn: 0.3857859	total: 6.11s	remaining: 4.09s
# 599:	learn: 0.3856249	total: 6.12s	remaining: 4.08s
# 600:	learn: 0.3854884	total: 6.13s	remaining: 4.07s
# 601:	learn: 0.3853555	total: 6.14s	remaining: 4.06s
# 602:	learn: 0.3851959	total: 6.15s	remaining: 4.05s
# 603:	learn: 0.3850651	total: 6.16s	remaining: 4.04s
# 604:	learn: 0.3849677	total: 6.17s	remaining: 4.03s
# 605:	learn: 0.3848700	total: 6.17s	remaining: 4.01s
# 606:	learn: 0.3847456	total: 6.18s	remaining: 4s
# 607:	learn: 0.3846218	total: 6.19s	remaining: 3.99s
# 608:	learn: 0.3844989	total: 6.2s	remaining: 3.98s
# 609:	learn: 0.3843636	total: 6.21s	remaining: 3.97s
# 610:	learn: 0.3842300	total: 6.22s	remaining: 3.96s
# 611:	learn: 0.3840966	total: 6.23s	remaining: 3.95s
# 612:	learn: 0.3839681	total: 6.24s	remaining: 3.94s
# 613:	learn: 0.3838362	total: 6.25s	remaining: 3.93s
# 614:	learn: 0.3837028	total: 6.25s	remaining: 3.92s
# 615:	learn: 0.3835731	total: 6.26s	remaining: 3.9s
# 616:	learn: 0.3834168	total: 6.27s	remaining: 3.89s
# 617:	learn: 0.3832580	total: 6.28s	remaining: 3.88s
# 618:	learn: 0.3831323	total: 6.29s	remaining: 3.87s
# 619:	learn: 0.3830064	total: 6.3s	remaining: 3.86s
# 620:	learn: 0.3828789	total: 6.31s	remaining: 3.85s
# 621:	learn: 0.3827265	total: 6.32s	remaining: 3.84s
# 622:	learn: 0.3826002	total: 6.33s	remaining: 3.83s
# 623:	learn: 0.3824512	total: 6.34s	remaining: 3.82s
# 624:	learn: 0.3823581	total: 6.35s	remaining: 3.81s
# 625:	learn: 0.3822294	total: 6.36s	remaining: 3.8s
# 626:	learn: 0.3821012	total: 6.37s	remaining: 3.79s
# 627:	learn: 0.3819540	total: 6.38s	remaining: 3.78s
# 628:	learn: 0.3818310	total: 6.39s	remaining: 3.77s
# 629:	learn: 0.3817123	total: 6.4s	remaining: 3.76s
# 630:	learn: 0.3816226	total: 6.41s	remaining: 3.75s
# 631:	learn: 0.3815332	total: 6.42s	remaining: 3.74s
# 632:	learn: 0.3814072	total: 6.43s	remaining: 3.73s
# 633:	learn: 0.3812834	total: 6.44s	remaining: 3.72s
# 634:	learn: 0.3811948	total: 6.45s	remaining: 3.71s
# 635:	learn: 0.3810720	total: 6.46s	remaining: 3.7s
# 636:	learn: 0.3809509	total: 6.47s	remaining: 3.69s
# 637:	learn: 0.3808321	total: 6.48s	remaining: 3.68s
# 638:	learn: 0.3807082	total: 6.49s	remaining: 3.67s
# 639:	learn: 0.3805919	total: 6.5s	remaining: 3.66s
# 640:	learn: 0.3804759	total: 6.51s	remaining: 3.65s
# 641:	learn: 0.3803601	total: 6.52s	remaining: 3.64s
# 642:	learn: 0.3802126	total: 6.53s	remaining: 3.63s
# 643:	learn: 0.3801268	total: 6.54s	remaining: 3.62s
# 644:	learn: 0.3800078	total: 6.55s	remaining: 3.61s
# 645:	learn: 0.3798947	total: 6.56s	remaining: 3.6s
# 646:	learn: 0.3797731	total: 6.57s	remaining: 3.58s
# 647:	learn: 0.3796533	total: 6.58s	remaining: 3.58s
# 648:	learn: 0.3795355	total: 6.59s	remaining: 3.56s
# 649:	learn: 0.3794200	total: 6.6s	remaining: 3.56s
# 650:	learn: 0.3793027	total: 6.61s	remaining: 3.54s
# 651:	learn: 0.3792192	total: 6.62s	remaining: 3.53s
# 652:	learn: 0.3791285	total: 6.63s	remaining: 3.52s
# 653:	learn: 0.3789831	total: 6.64s	remaining: 3.51s
# 654:	learn: 0.3788669	total: 6.65s	remaining: 3.5s
# 655:	learn: 0.3787592	total: 6.66s	remaining: 3.49s
# 656:	learn: 0.3786152	total: 6.67s	remaining: 3.48s
# 657:	learn: 0.3785009	total: 6.68s	remaining: 3.47s
# 658:	learn: 0.3783850	total: 6.69s	remaining: 3.46s
# 659:	learn: 0.3782441	total: 6.7s	remaining: 3.45s
# 660:	learn: 0.3781311	total: 6.71s	remaining: 3.44s
# 661:	learn: 0.3780258	total: 6.72s	remaining: 3.43s
# 662:	learn: 0.3779099	total: 6.74s	remaining: 3.42s
# 663:	learn: 0.3777700	total: 6.75s	remaining: 3.42s
# 664:	learn: 0.3776331	total: 6.76s	remaining: 3.41s
# 665:	learn: 0.3775178	total: 6.77s	remaining: 3.4s
# 666:	learn: 0.3774065	total: 6.78s	remaining: 3.39s
# 667:	learn: 0.3772949	total: 6.79s	remaining: 3.38s
# 668:	learn: 0.3771846	total: 6.8s	remaining: 3.37s
# 669:	learn: 0.3770732	total: 6.81s	remaining: 3.35s
# 670:	learn: 0.3769382	total: 6.82s	remaining: 3.35s
# 671:	learn: 0.3768588	total: 6.83s	remaining: 3.33s
# 672:	learn: 0.3767796	total: 6.84s	remaining: 3.33s
# 673:	learn: 0.3766711	total: 6.85s	remaining: 3.31s
# 674:	learn: 0.3765635	total: 6.86s	remaining: 3.3s
# 675:	learn: 0.3764620	total: 6.87s	remaining: 3.29s
# 676:	learn: 0.3763508	total: 6.88s	remaining: 3.28s
# 677:	learn: 0.3762201	total: 6.89s	remaining: 3.27s
# 678:	learn: 0.3761408	total: 6.91s	remaining: 3.26s
# 679:	learn: 0.3760394	total: 6.92s	remaining: 3.25s
# 680:	learn: 0.3759306	total: 6.92s	remaining: 3.24s
# 681:	learn: 0.3758242	total: 6.94s	remaining: 3.23s
# 682:	learn: 0.3757170	total: 6.95s	remaining: 3.22s
# 683:	learn: 0.3755877	total: 6.96s	remaining: 3.21s
# 684:	learn: 0.3754790	total: 6.97s	remaining: 3.2s
# 685:	learn: 0.3753782	total: 6.98s	remaining: 3.19s
# 686:	learn: 0.3752723	total: 6.99s	remaining: 3.18s
# 687:	learn: 0.3751419	total: 7s	remaining: 3.17s
# 688:	learn: 0.3750423	total: 7.01s	remaining: 3.17s
# 689:	learn: 0.3749365	total: 7.03s	remaining: 3.16s
# 690:	learn: 0.3748369	total: 7.04s	remaining: 3.15s
# 691:	learn: 0.3747090	total: 7.05s	remaining: 3.14s
# 692:	learn: 0.3746053	total: 7.06s	remaining: 3.13s
# 693:	learn: 0.3744791	total: 7.07s	remaining: 3.12s
# 694:	learn: 0.3743769	total: 7.08s	remaining: 3.11s
# 695:	learn: 0.3742782	total: 7.09s	remaining: 3.1s
# 696:	learn: 0.3741545	total: 7.1s	remaining: 3.09s
# 697:	learn: 0.3740791	total: 7.11s	remaining: 3.08s
# 698:	learn: 0.3739771	total: 7.12s	remaining: 3.07s
# 699:	learn: 0.3738811	total: 7.13s	remaining: 3.06s
# 700:	learn: 0.3738092	total: 7.14s	remaining: 3.04s
# 701:	learn: 0.3737059	total: 7.15s	remaining: 3.04s
# 702:	learn: 0.3735827	total: 7.16s	remaining: 3.02s
# 703:	learn: 0.3734825	total: 7.17s	remaining: 3.01s
# 704:	learn: 0.3733824	total: 7.18s	remaining: 3s
# 705:	learn: 0.3732624	total: 7.19s	remaining: 2.99s
# 706:	learn: 0.3731669	total: 7.2s	remaining: 2.98s
# 707:	learn: 0.3730704	total: 7.21s	remaining: 2.97s
# 708:	learn: 0.3729983	total: 7.22s	remaining: 2.96s
# 709:	learn: 0.3729053	total: 7.23s	remaining: 2.95s
# 710:	learn: 0.3728049	total: 7.24s	remaining: 2.94s
# 711:	learn: 0.3727033	total: 7.24s	remaining: 2.93s
# 712:	learn: 0.3726035	total: 7.25s	remaining: 2.92s
# 713:	learn: 0.3725122	total: 7.26s	remaining: 2.91s
# 714:	learn: 0.3724128	total: 7.27s	remaining: 2.9s
# 715:	learn: 0.3723160	total: 7.28s	remaining: 2.89s
# 716:	learn: 0.3722166	total: 7.29s	remaining: 2.88s
# 717:	learn: 0.3721261	total: 7.3s	remaining: 2.87s
# 718:	learn: 0.3720317	total: 7.31s	remaining: 2.85s
# 719:	learn: 0.3719335	total: 7.32s	remaining: 2.85s
# 720:	learn: 0.3718651	total: 7.33s	remaining: 2.83s
# 721:	learn: 0.3717686	total: 7.34s	remaining: 2.82s
# 722:	learn: 0.3716807	total: 7.34s	remaining: 2.81s
# 723:	learn: 0.3715838	total: 7.35s	remaining: 2.8s
# 724:	learn: 0.3714907	total: 7.36s	remaining: 2.79s
# 725:	learn: 0.3713971	total: 7.37s	remaining: 2.78s
# 726:	learn: 0.3712782	total: 7.38s	remaining: 2.77s
# 727:	learn: 0.3711903	total: 7.39s	remaining: 2.76s
# 728:	learn: 0.3711023	total: 7.4s	remaining: 2.75s
# 729:	learn: 0.3709848	total: 7.41s	remaining: 2.74s
# 730:	learn: 0.3708962	total: 7.42s	remaining: 2.73s
# 731:	learn: 0.3708011	total: 7.43s	remaining: 2.72s
# 732:	learn: 0.3707081	total: 7.44s	remaining: 2.71s
# 733:	learn: 0.3705934	total: 7.45s	remaining: 2.7s
# 734:	learn: 0.3705041	total: 7.45s	remaining: 2.69s
# 735:	learn: 0.3704153	total: 7.46s	remaining: 2.68s
# 736:	learn: 0.3703501	total: 7.47s	remaining: 2.67s
# 737:	learn: 0.3702567	total: 7.48s	remaining: 2.65s
# 738:	learn: 0.3701908	total: 7.49s	remaining: 2.65s
# 739:	learn: 0.3700766	total: 7.5s	remaining: 2.63s
# 740:	learn: 0.3699905	total: 7.51s	remaining: 2.62s
# 741:	learn: 0.3698985	total: 7.52s	remaining: 2.61s
# 742:	learn: 0.3698146	total: 7.53s	remaining: 2.6s
# 743:	learn: 0.3697013	total: 7.54s	remaining: 2.59s
# 744:	learn: 0.3696114	total: 7.54s	remaining: 2.58s
# 745:	learn: 0.3695433	total: 7.55s	remaining: 2.57s
# 746:	learn: 0.3694597	total: 7.56s	remaining: 2.56s
# 747:	learn: 0.3693964	total: 7.57s	remaining: 2.55s
# 748:	learn: 0.3693058	total: 7.58s	remaining: 2.54s
# 749:	learn: 0.3691961	total: 7.59s	remaining: 2.53s
# 750:	learn: 0.3690877	total: 7.6s	remaining: 2.52s
# 751:	learn: 0.3690036	total: 7.61s	remaining: 2.51s
# 752:	learn: 0.3689424	total: 7.62s	remaining: 2.5s
# 753:	learn: 0.3688556	total: 7.63s	remaining: 2.49s
# 754:	learn: 0.3687678	total: 7.64s	remaining: 2.48s
# 755:	learn: 0.3687053	total: 7.64s	remaining: 2.47s
# 756:	learn: 0.3686164	total: 7.65s	remaining: 2.46s
# 757:	learn: 0.3685093	total: 7.66s	remaining: 2.45s
# 758:	learn: 0.3684431	total: 7.67s	remaining: 2.44s
# 759:	learn: 0.3683374	total: 7.68s	remaining: 2.42s
# 760:	learn: 0.3682338	total: 7.69s	remaining: 2.41s
# 761:	learn: 0.3681527	total: 7.7s	remaining: 2.4s
# 762:	learn: 0.3680915	total: 7.71s	remaining: 2.39s
# 763:	learn: 0.3680035	total: 7.72s	remaining: 2.38s
# 764:	learn: 0.3679169	total: 7.72s	remaining: 2.37s
# 765:	learn: 0.3678378	total: 7.74s	remaining: 2.36s
# 766:	learn: 0.3677765	total: 7.74s	remaining: 2.35s
# 767:	learn: 0.3676893	total: 7.75s	remaining: 2.34s
# 768:	learn: 0.3676062	total: 7.76s	remaining: 2.33s
# 769:	learn: 0.3675233	total: 7.77s	remaining: 2.32s
# 770:	learn: 0.3674377	total: 7.78s	remaining: 2.31s
# 771:	learn: 0.3673521	total: 7.79s	remaining: 2.3s
# 772:	learn: 0.3672673	total: 7.8s	remaining: 2.29s
# 773:	learn: 0.3671861	total: 7.81s	remaining: 2.28s
# 774:	learn: 0.3671012	total: 7.82s	remaining: 2.27s
# 775:	learn: 0.3670240	total: 7.83s	remaining: 2.26s
# 776:	learn: 0.3669403	total: 7.84s	remaining: 2.25s
# 777:	learn: 0.3668800	total: 7.84s	remaining: 2.24s
# 778:	learn: 0.3667771	total: 7.86s	remaining: 2.23s
# 779:	learn: 0.3666973	total: 7.86s	remaining: 2.22s
# 780:	learn: 0.3666139	total: 7.87s	remaining: 2.21s
# 781:	learn: 0.3665547	total: 7.88s	remaining: 2.2s
# 782:	learn: 0.3664950	total: 7.89s	remaining: 2.19s
# 783:	learn: 0.3664135	total: 7.9s	remaining: 2.18s
# 784:	learn: 0.3663371	total: 7.91s	remaining: 2.17s
# 785:	learn: 0.3662544	total: 7.92s	remaining: 2.16s
# 786:	learn: 0.3661767	total: 7.93s	remaining: 2.15s
# 787:	learn: 0.3660965	total: 7.94s	remaining: 2.13s
# 788:	learn: 0.3659963	total: 7.95s	remaining: 2.13s
# 789:	learn: 0.3659375	total: 7.96s	remaining: 2.12s
# 790:	learn: 0.3658803	total: 7.96s	remaining: 2.1s
# 791:	learn: 0.3658048	total: 7.97s	remaining: 2.09s
# 792:	learn: 0.3657256	total: 7.98s	remaining: 2.08s
# 793:	learn: 0.3656464	total: 7.99s	remaining: 2.07s
# 794:	learn: 0.3655882	total: 8s	remaining: 2.06s
# 795:	learn: 0.3655111	total: 8.01s	remaining: 2.05s
# 796:	learn: 0.3654118	total: 8.02s	remaining: 2.04s
# 797:	learn: 0.3653140	total: 8.03s	remaining: 2.03s
# 798:	learn: 0.3652575	total: 8.04s	remaining: 2.02s
# 799:	learn: 0.3651966	total: 8.05s	remaining: 2.01s
# 800:	learn: 0.3651163	total: 8.06s	remaining: 2s
# 801:	learn: 0.3650602	total: 8.06s	remaining: 1.99s
# 802:	learn: 0.3650034	total: 8.07s	remaining: 1.98s
# 803:	learn: 0.3649282	total: 8.08s	remaining: 1.97s
# 804:	learn: 0.3648721	total: 8.09s	remaining: 1.96s
# 805:	learn: 0.3647953	total: 8.1s	remaining: 1.95s
# 806:	learn: 0.3647396	total: 8.11s	remaining: 1.94s
# 807:	learn: 0.3646845	total: 8.12s	remaining: 1.93s
# 808:	learn: 0.3646303	total: 8.13s	remaining: 1.92s
# 809:	learn: 0.3645554	total: 8.14s	remaining: 1.91s
# 810:	learn: 0.3644846	total: 8.15s	remaining: 1.9s
# 811:	learn: 0.3643879	total: 8.16s	remaining: 1.89s
# 812:	learn: 0.3643088	total: 8.16s	remaining: 1.88s
# 813:	learn: 0.3642312	total: 8.18s	remaining: 1.87s
# 814:	learn: 0.3641601	total: 8.18s	remaining: 1.86s
# 815:	learn: 0.3641056	total: 8.19s	remaining: 1.85s
# 816:	learn: 0.3640327	total: 8.2s	remaining: 1.84s
# 817:	learn: 0.3639634	total: 8.21s	remaining: 1.83s
# 818:	learn: 0.3638862	total: 8.22s	remaining: 1.82s
# 819:	learn: 0.3638346	total: 8.23s	remaining: 1.81s
# 820:	learn: 0.3637648	total: 8.24s	remaining: 1.8s
# 821:	learn: 0.3636707	total: 8.25s	remaining: 1.79s
# 822:	learn: 0.3635952	total: 8.26s	remaining: 1.77s
# 823:	learn: 0.3635421	total: 8.27s	remaining: 1.76s
# 824:	learn: 0.3634659	total: 8.27s	remaining: 1.75s
# 825:	learn: 0.3633910	total: 8.28s	remaining: 1.74s
# 826:	learn: 0.3633167	total: 8.29s	remaining: 1.73s
# 827:	learn: 0.3632421	total: 8.3s	remaining: 1.72s
# 828:	learn: 0.3631884	total: 8.31s	remaining: 1.71s
# 829:	learn: 0.3631150	total: 8.32s	remaining: 1.7s
# 830:	learn: 0.3630220	total: 8.33s	remaining: 1.69s
# 831:	learn: 0.3629299	total: 8.34s	remaining: 1.68s
# 832:	learn: 0.3628387	total: 8.35s	remaining: 1.67s
# 833:	learn: 0.3627715	total: 8.36s	remaining: 1.66s
# 834:	learn: 0.3626993	total: 8.37s	remaining: 1.65s
# 835:	learn: 0.3626285	total: 8.38s	remaining: 1.64s
# 836:	learn: 0.3625782	total: 8.38s	remaining: 1.63s
# 837:	learn: 0.3625264	total: 8.39s	remaining: 1.62s
# 838:	learn: 0.3624738	total: 8.4s	remaining: 1.61s
# 839:	learn: 0.3624011	total: 8.41s	remaining: 1.6s
# 840:	learn: 0.3623119	total: 8.42s	remaining: 1.59s
# 841:	learn: 0.3622395	total: 8.43s	remaining: 1.58s
# 842:	learn: 0.3621518	total: 8.44s	remaining: 1.57s
# 843:	learn: 0.3621006	total: 8.45s	remaining: 1.56s
# 844:	learn: 0.3620305	total: 8.46s	remaining: 1.55s
# 845:	learn: 0.3619438	total: 8.46s	remaining: 1.54s
# 846:	learn: 0.3618569	total: 8.47s	remaining: 1.53s
# 847:	learn: 0.3617852	total: 8.48s	remaining: 1.52s
# 848:	learn: 0.3617204	total: 8.49s	remaining: 1.51s
# 849:	learn: 0.3616547	total: 8.5s	remaining: 1.5s
# 850:	learn: 0.3615853	total: 8.51s	remaining: 1.49s
# 851:	learn: 0.3615345	total: 8.52s	remaining: 1.48s
# 852:	learn: 0.3614689	total: 8.53s	remaining: 1.47s
# 853:	learn: 0.3614039	total: 8.54s	remaining: 1.46s
# 854:	learn: 0.3613550	total: 8.54s	remaining: 1.45s
# 855:	learn: 0.3612883	total: 8.56s	remaining: 1.44s
# 856:	learn: 0.3612387	total: 8.56s	remaining: 1.43s
# 857:	learn: 0.3611890	total: 8.57s	remaining: 1.42s
# 858:	learn: 0.3611406	total: 8.58s	remaining: 1.41s
# 859:	learn: 0.3610710	total: 8.59s	remaining: 1.4s
# 860:	learn: 0.3610074	total: 8.6s	remaining: 1.39s
# 861:	learn: 0.3609588	total: 8.61s	remaining: 1.38s
# 862:	learn: 0.3609116	total: 8.62s	remaining: 1.37s
# 863:	learn: 0.3608409	total: 8.63s	remaining: 1.36s
# 864:	learn: 0.3607557	total: 8.63s	remaining: 1.35s
# 865:	learn: 0.3606942	total: 8.64s	remaining: 1.34s
# 866:	learn: 0.3606249	total: 8.65s	remaining: 1.33s
# 867:	learn: 0.3605413	total: 8.66s	remaining: 1.32s
# 868:	learn: 0.3604740	total: 8.67s	remaining: 1.31s
# 869:	learn: 0.3604131	total: 8.68s	remaining: 1.3s
# 870:	learn: 0.3603436	total: 8.69s	remaining: 1.29s
# 871:	learn: 0.3602738	total: 8.7s	remaining: 1.28s
# 872:	learn: 0.3602058	total: 8.71s	remaining: 1.27s
# 873:	learn: 0.3601586	total: 8.72s	remaining: 1.26s
# 874:	learn: 0.3600912	total: 8.72s	remaining: 1.25s
# 875:	learn: 0.3600265	total: 8.73s	remaining: 1.24s
# 876:	learn: 0.3599805	total: 8.74s	remaining: 1.23s
# 877:	learn: 0.3599137	total: 8.75s	remaining: 1.22s
# 878:	learn: 0.3598675	total: 8.76s	remaining: 1.21s
# 879:	learn: 0.3598008	total: 8.77s	remaining: 1.2s
# 880:	learn: 0.3597354	total: 8.78s	remaining: 1.19s
# 881:	learn: 0.3596700	total: 8.79s	remaining: 1.18s
# 882:	learn: 0.3595873	total: 8.8s	remaining: 1.17s
# 883:	learn: 0.3595409	total: 8.81s	remaining: 1.16s
# 884:	learn: 0.3594599	total: 8.81s	remaining: 1.15s
# 885:	learn: 0.3594009	total: 8.82s	remaining: 1.14s
# 886:	learn: 0.3593353	total: 8.83s	remaining: 1.13s
# 887:	learn: 0.3592558	total: 8.84s	remaining: 1.11s
# 888:	learn: 0.3591927	total: 8.85s	remaining: 1.1s
# 889:	learn: 0.3591471	total: 8.86s	remaining: 1.09s
# 890:	learn: 0.3590870	total: 8.87s	remaining: 1.08s
# 891:	learn: 0.3590414	total: 8.88s	remaining: 1.07s
# 892:	learn: 0.3589935	total: 8.89s	remaining: 1.06s
# 893:	learn: 0.3589477	total: 8.89s	remaining: 1.05s
# 894:	learn: 0.3588893	total: 8.9s	remaining: 1.04s
# 895:	learn: 0.3588279	total: 8.91s	remaining: 1.03s
# 896:	learn: 0.3587833	total: 8.92s	remaining: 1.02s
# 897:	learn: 0.3587219	total: 8.93s	remaining: 1.01s
# 898:	learn: 0.3586578	total: 8.94s	remaining: 1s
# 899:	learn: 0.3585796	total: 8.95s	remaining: 995ms
# 900:	learn: 0.3585024	total: 8.96s	remaining: 985ms
# 901:	learn: 0.3584387	total: 8.97s	remaining: 975ms
# 902:	learn: 0.3583752	total: 8.98s	remaining: 965ms
# 903:	learn: 0.3583182	total: 8.99s	remaining: 955ms
# 904:	learn: 0.3582737	total: 9s	remaining: 945ms
# 905:	learn: 0.3582165	total: 9.01s	remaining: 935ms
# 906:	learn: 0.3581557	total: 9.02s	remaining: 925ms
# 907:	learn: 0.3580997	total: 9.03s	remaining: 915ms
# 908:	learn: 0.3580409	total: 9.04s	remaining: 905ms
# 909:	learn: 0.3579983	total: 9.05s	remaining: 895ms
# 910:	learn: 0.3579396	total: 9.06s	remaining: 885ms
# 911:	learn: 0.3578840	total: 9.07s	remaining: 875ms
# 912:	learn: 0.3578217	total: 9.08s	remaining: 865ms
# 913:	learn: 0.3577603	total: 9.09s	remaining: 855ms
# 914:	learn: 0.3577055	total: 9.1s	remaining: 845ms
# 915:	learn: 0.3576620	total: 9.11s	remaining: 835ms
# 916:	learn: 0.3575998	total: 9.12s	remaining: 825ms
# 917:	learn: 0.3575392	total: 9.13s	remaining: 815ms
# 918:	learn: 0.3574622	total: 9.13s	remaining: 805ms
# 919:	learn: 0.3574207	total: 9.14s	remaining: 795ms
# 920:	learn: 0.3573454	total: 9.15s	remaining: 785ms
# 921:	learn: 0.3573020	total: 9.16s	remaining: 775ms
# 922:	learn: 0.3572407	total: 9.17s	remaining: 765ms
# 923:	learn: 0.3571983	total: 9.18s	remaining: 755ms
# 924:	learn: 0.3571388	total: 9.19s	remaining: 745ms
# 925:	learn: 0.3570970	total: 9.2s	remaining: 735ms
# 926:	learn: 0.3570550	total: 9.21s	remaining: 725ms
# 927:	learn: 0.3569964	total: 9.22s	remaining: 715ms
# 928:	learn: 0.3569558	total: 9.22s	remaining: 705ms
# 929:	learn: 0.3569133	total: 9.23s	remaining: 695ms
# 930:	learn: 0.3568723	total: 9.24s	remaining: 685ms
# 931:	learn: 0.3568136	total: 9.25s	remaining: 675ms
# 932:	learn: 0.3567718	total: 9.26s	remaining: 665ms
# 933:	learn: 0.3567117	total: 9.27s	remaining: 655ms
# 934:	learn: 0.3566555	total: 9.28s	remaining: 645ms
# 935:	learn: 0.3565954	total: 9.29s	remaining: 635ms
# 936:	learn: 0.3565370	total: 9.29s	remaining: 625ms
# 937:	learn: 0.3564843	total: 9.3s	remaining: 615ms
# 938:	learn: 0.3564280	total: 9.31s	remaining: 605ms
# 939:	learn: 0.3563702	total: 9.32s	remaining: 595ms
# 940:	learn: 0.3562961	total: 9.33s	remaining: 585ms
# 941:	learn: 0.3562553	total: 9.34s	remaining: 575ms
# 942:	learn: 0.3562012	total: 9.35s	remaining: 565ms
# 943:	learn: 0.3561442	total: 9.36s	remaining: 555ms
# 944:	learn: 0.3560889	total: 9.37s	remaining: 545ms
# 945:	learn: 0.3560475	total: 9.38s	remaining: 535ms
# 946:	learn: 0.3560065	total: 9.39s	remaining: 525ms
# 947:	learn: 0.3559336	total: 9.4s	remaining: 515ms
# 948:	learn: 0.3558762	total: 9.41s	remaining: 506ms
# 949:	learn: 0.3558199	total: 9.42s	remaining: 496ms
# 950:	learn: 0.3557643	total: 9.43s	remaining: 486ms
# 951:	learn: 0.3557238	total: 9.44s	remaining: 476ms
# 952:	learn: 0.3556826	total: 9.45s	remaining: 466ms
# 953:	learn: 0.3556267	total: 9.45s	remaining: 456ms
# 954:	learn: 0.3555728	total: 9.46s	remaining: 446ms
# 955:	learn: 0.3555337	total: 9.47s	remaining: 436ms
# 956:	learn: 0.3554928	total: 9.48s	remaining: 426ms
# 957:	learn: 0.3554384	total: 9.49s	remaining: 416ms
# 958:	learn: 0.3553830	total: 9.5s	remaining: 406ms
# 959:	learn: 0.3553112	total: 9.51s	remaining: 396ms
# 960:	learn: 0.3552721	total: 9.52s	remaining: 386ms
# 961:	learn: 0.3552320	total: 9.53s	remaining: 376ms
# 962:	learn: 0.3551927	total: 9.53s	remaining: 366ms
# 963:	learn: 0.3551223	total: 9.54s	remaining: 356ms
# 964:	learn: 0.3550681	total: 9.55s	remaining: 347ms
# 965:	learn: 0.3550289	total: 9.56s	remaining: 337ms
# 966:	learn: 0.3549894	total: 9.57s	remaining: 327ms
# 967:	learn: 0.3549205	total: 9.58s	remaining: 317ms
# 968:	learn: 0.3548697	total: 9.59s	remaining: 307ms
# 969:	learn: 0.3548147	total: 9.6s	remaining: 297ms
# 970:	learn: 0.3547605	total: 9.61s	remaining: 287ms
# 971:	learn: 0.3547214	total: 9.62s	remaining: 277ms
# 972:	learn: 0.3546809	total: 9.63s	remaining: 267ms
# 973:	learn: 0.3546435	total: 9.64s	remaining: 257ms
# 974:	learn: 0.3545938	total: 9.64s	remaining: 247ms
# 975:	learn: 0.3545560	total: 9.65s	remaining: 237ms
# 976:	learn: 0.3545029	total: 9.66s	remaining: 227ms
# 977:	learn: 0.3544339	total: 9.67s	remaining: 218ms
# 978:	learn: 0.3543837	total: 9.68s	remaining: 208ms
# 979:	learn: 0.3543469	total: 9.69s	remaining: 198ms
# 980:	learn: 0.3542788	total: 9.7s	remaining: 188ms
# 981:	learn: 0.3542400	total: 9.71s	remaining: 178ms
# 982:	learn: 0.3541871	total: 9.72s	remaining: 168ms
# 983:	learn: 0.3541199	total: 9.74s	remaining: 158ms
# 984:	learn: 0.3540836	total: 9.75s	remaining: 148ms
# 985:	learn: 0.3540171	total: 9.76s	remaining: 139ms
# 986:	learn: 0.3539637	total: 9.78s	remaining: 129ms
# 987:	learn: 0.3539128	total: 9.8s	remaining: 119ms
# 988:	learn: 0.3538745	total: 9.81s	remaining: 109ms
# 989:	learn: 0.3538236	total: 9.83s	remaining: 99.3ms
# 990:	learn: 0.3537855	total: 9.84s	remaining: 89.4ms
# 991:	learn: 0.3537483	total: 9.86s	remaining: 79.5ms
# 992:	learn: 0.3537098	total: 9.87s	remaining: 69.6ms
# 993:	learn: 0.3536620	total: 9.89s	remaining: 59.7ms
# 994:	learn: 0.3536109	total: 9.9s	remaining: 49.8ms
# 995:	learn: 0.3535729	total: 9.92s	remaining: 39.8ms
# 996:	learn: 0.3535199	total: 9.94s	remaining: 29.9ms
# 997:	learn: 0.3534708	total: 9.95s	remaining: 19.9ms
# 998:	learn: 0.3534230	total: 9.97s	remaining: 9.98ms
# 999:	learn: 0.3533848	total: 9.99s	remaining: 0us
#                model_name  train_accuracy  test_accuracy  train_precision  \
# 0      LogisticRegression           0.848          0.849            0.874
# 1  DecisionTreeClassifier           0.935          0.935            0.897
# 2  RandomForestClassifier           0.936          0.936            0.898
# 3           XGBClassifier           0.914          0.914            0.900
# 4    KNeighborsClassifier           1.000          0.907            1.000
# 5              StackingLR           0.934          0.934            0.898
# 6             StackingXGB           0.936          0.937            0.897
# 7          LGBMClassifier           0.910          0.910            0.900
# 8      CatBoostClassifier           0.884          0.885            0.899
#
#    test_precision  train_recall  test_recall  train_f1  test_f1  \
# 0           0.873         0.849        0.852     0.861    0.863
# 1           0.898         0.997        0.997     0.944    0.945
# 2           0.898         0.998        0.998     0.945    0.946
# 3           0.900         0.952        0.951     0.925    0.925
# 4           0.901         1.000        0.935     1.000    0.918
# 5           0.898         0.994        0.994     0.943    0.944
# 6           0.898         0.999        0.999     0.946    0.946
# 7           0.900         0.943        0.941     0.921    0.920
# 8           0.900         0.892        0.893     0.896    0.896
#
#    train_roc_auc  test_roc_auc  train_log_loss  test_log_loss
# 0          0.908         0.910           0.390          0.388
# 1          0.962         0.953           0.182          0.191
# 2          0.996         0.954           0.162          0.186
# 3          0.950         0.949           0.251          0.252
# 4          1.000         0.938           0.000          0.896
# 5          0.953         0.953           0.198          0.197
# 6          0.953         0.953           0.182          0.181
# 7          0.947         0.947           0.269          0.268
# 8          0.938         0.938           0.353          0.352

# %% [markdown]
# #### AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
def objective(trial, xtrain, ytrain, kf):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 10, 501, 50),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1e0),
    }
    model = AdaBoostClassifier(**params)
    scores = cross_validate(model, xtrain, ytrain, cv=kf, scoring='neg_log_loss', n_jobs=-1)
    loss = -scores['test_score'].mean()
    return loss

kf = KFold(n_splits=3, shuffle=True, random_state=42)
obj_func = lambda trial: objective(trial, xtrain.values, ytrain.values.ravel(), kf)
study = optuna.create_study(direction='minimize',)
study.optimize(obj_func, n_trials=50)

print(f"Best score: {study.best_value:5f}")
print(f"Best params: {study.best_params}")

best_model = AdaBoostClassifier(**study.best_params).fit(xtrain.values, ytrain.values.ravel())
model_performance, estimators = add_model_performance(model_name='AdaBoostClassifier', clf=best_model, df=model_performance, model_dict=estimators)

display(model_performance)
# Out:
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /Users/psykick/Documents/learning/github/customer-churn-prediction-kaggle/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Best score: 0.526830
# Best params: {'n_estimators': 10, 'learning_rate': 0.0054699267053919896}
#                model_name  train_accuracy  test_accuracy  train_precision  \
# 0      LogisticRegression           0.848          0.849            0.874
# 1  DecisionTreeClassifier           0.935          0.935            0.897
# 2  RandomForestClassifier           0.936          0.936            0.898
# 3           XGBClassifier           0.914          0.914            0.900
# 4    KNeighborsClassifier           1.000          0.907            1.000
# 5              StackingLR           0.934          0.934            0.898
# 6             StackingXGB           0.936          0.937            0.897
# 7          LGBMClassifier           0.910          0.910            0.900
# 8      CatBoostClassifier           0.884          0.885            0.899
# 9      AdaBoostClassifier           0.740          0.742            0.907
#
#    test_precision  train_recall  test_recall  train_f1  test_f1  \
# 0           0.873         0.849        0.852     0.861    0.863
# 1           0.898         0.997        0.997     0.944    0.945
# 2           0.898         0.998        0.998     0.945    0.946
# 3           0.900         0.952        0.951     0.925    0.925
# 4           0.901         1.000        0.935     1.000    0.918
# 5           0.898         0.994        0.994     0.943    0.944
# 6           0.898         0.999        0.999     0.946    0.946
# 7           0.900         0.943        0.941     0.921    0.920
# 8           0.900         0.892        0.893     0.896    0.896
# 9           0.909         0.592        0.595     0.717    0.719
#
#    train_roc_auc  test_roc_auc  train_log_loss  test_log_loss
# 0          0.908         0.910           0.390          0.388
# 1          0.962         0.953           0.182          0.191
# 2          0.996         0.954           0.162          0.186
# 3          0.950         0.949           0.251          0.252
# 4          1.000         0.938           0.000          0.896
# 5          0.953         0.953           0.198          0.197
# 6          0.953         0.953           0.182          0.181
# 7          0.947         0.947           0.269          0.268
# 8          0.938         0.938           0.353          0.352
# 9          0.758         0.760           0.527          0.524

# %%
# saving the models, model performance and estimators
for model_name, model in estimators.items():
    with open(f'data/{model_name}_final.pkl', 'wb') as f:
        pickle.dump(model, f)
with open('data/model_performance_final.pkl', 'wb') as f:
    pickle.dump(model_performance, f)
with open('data/estimators_final.pkl', 'wb') as f:
    pickle.dump(estimators, f)

# %% [markdown]
# # Conclusion
# The best model out of all the trained ones is Stacking Classifier with XGBoost as the final model.
